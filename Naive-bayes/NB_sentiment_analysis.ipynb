# %%
import nltk
from nltk.corpus import stopwords, twitter_samples
import numpy as np
import pandas as pd
import string
from nltk.tokenize import TweetTokenizer
import matplotlib.pyplot as plt
import random
import re
import seaborn as sns
from nltk.stem import PorterStemmer
nltk.download('twitter samples')
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading twitter samples: Package 'twitter samples'
# [nltk_data]     not found in index
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')

# %%
len(positive_tweets)
# Out:
# 5000

# %%
test_pos = positive_tweets[4000:]
train_pos = positive_tweets[:4000]
test_neg = negative_tweets[4000:]
train_neg = negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# %%
train_y = np.append(np.ones(len(train_pos)),np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)),np.zeros(len(test_neg)))

# %%
plt.bar(['Positive Tweets','Negative Tweets'],[len(positive_tweets),len(negative_tweets)],color='orange')
# Out:
# <BarContainer object of 2 artists>

# %%
plt.bar(['Training set','Test set'],[len(train_x),len(test_x)])
# Out:
# <BarContainer object of 2 artists>

# %%
#check postive tweets
print('Positive tweet example: ' + positive_tweets[random.randint(0,5000)])
# Out:
# Positive tweet example: @AndyCCochrane I hope you're enjoying your ride Andy. :) ^NB

# %%
#check negative tweets
print('Negative tweet example: ' + negative_tweets[random.randint(0,5000)])
# Out:
# Negative tweet example: @halehydruh i dont know huhu tests kasi namin and i didnt finish my AP test :-(

# %% [markdown]
# THIS CSV FILE CONSISTS OF VALUES OF POSITIVE LOG PROBABILITY, NEGATIVE LOG PROBABILITY AND ASSOCIATED LABEL

# %%
features = pd.read_csv('bayes_features.csv')

# %%
features
# Out:
#         positive    negative  sentiment
# 0     -45.763393  -63.351354        1.0
# 1    -105.491568 -114.204862        1.0
# 2     -57.028078  -67.216467        1.0
# 3     -10.055885  -18.589057        1.0
# 4    -125.749270 -138.334845        1.0
# ...          ...         ...        ...
# 7995  -46.214113  -35.639696        0.0
# 7996  -23.784088  -19.383425        0.0
# 7997  -57.879612  -47.805972        0.0
# 7998  -55.850759  -46.148073        0.0
# 7999  -81.481710  -74.909428        0.0
#
# [8000 rows x 3 columns]

# %%
colors = ['blue', 'orange']
sentiments = ['negative', 'positive']

# Create a scatter plot using seaborn
plt.figure(figsize=(8, 8))
sns.scatterplot(x='positive', y='negative', hue='sentiment', data=features, palette=colors, s=5, marker='*')

# Custom limits for this chart
plt.xlim(-250, 0)
plt.ylim(-250, 0)

plt.xlabel("Positive")
plt.ylabel("Negative")

# Add a legend
plt.legend(title='Sentiment', labels=sentiments)

plt.show()

# %% [markdown]
# START OF PREPROCESSING OF TEXT

# %% [markdown]
# Preprocessing Steps
# <ul>
#     <li>Tokenizing the string</li>
#     <li>Lowercasing</li>
#     <li>Removal of stop words</li>
#     <li>Stemming</li>
# </ul>

# %%
def preprocess(tweet):
    #remove retweet text "RT"
    tweet2 = re.sub(r'^RT[\s]+','',tweet)

    #remove hyperlinks
    tweet2 = re.sub(r'https?://[^\s\n\r]+','',tweet2)

    #remove hastag from front of the word
    tweet2 = re.sub(r'#','',tweet2)


    #tokenizer tweet
    tokenizer = TweetTokenizer(preserve_case=False,strip_handles=True,reduce_len=True)

    tweet_tokens = tokenizer.tokenize(tweet2)


    #remove stopwords and punctuations
    tweets_clean = []
    stopwords_english = stopwords.words('english')
    for word in tweet_tokens:
        if (word not in stopwords_english and 
            word not in string.punctuation):
            tweets_clean.append(word)


    #perform stemming        
    stemmer = PorterStemmer()
    tweets_stem = []
    for word in tweets_clean:
        stem_word = stemmer.stem(word)
        tweets_stem.append(stem_word)
    

    return tweets_stem

# %%
def count_tweets(result,tweets,ys):
    for y,tweet in zip(ys,tweets):
        for word in preprocess(tweet):
            pair = (word,y)
            if pair in result:
                result[pair] +=1
            else:
                result[pair] = 1
    
    return result

# %%
freq = count_tweets({},train_x,train_y)

# %%
def naive_bayes_train(freq,train_x,train_y):

    loglikelihood={}
    #create vocab
    words = [key[0] for key in freq.keys()]
    vocab = set(words)
    V = len(vocab)

    #calculate number or positive and negative words
    N_pos = N_neg = 0
    for pair in freq.keys():
        if pair[1] > 0:
            N_pos += freq[pair]
        else:
            N_neg += freq[pair]

    #calculating total number of tweets in train
    D = len(train_y)
    D_pos = sum(train_y)
    D_neg = D - D_pos

    logprior = np.log(D_pos) - np.log(D_neg)
    
    # For each word in the vocabulary...
    for word in vocab:
        # get the positive and negative frequency of the word
        freq_pos = freq.get((word, 1), 0)
        freq_neg = freq.get((word, 0), 0)

        # calculate the probability that each word is positive, and negative
        p_w_pos = (freq_pos + 1) / (N_pos + V)
        p_w_neg = (freq_neg + 1) / (N_neg + V)

        # calculate the log likelihood of the word
        loglikelihood[word] = np.log(p_w_pos / p_w_neg)

    return logprior, loglikelihood

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
    #preprocess the test tweet
    word_l = preprocess(tweet)

    #assign the value of logprior to p
    p = logprior

    #for all the words in processed tweet calcualte loglikehood
    for word in word_l:
        if word in loglikelihood:
            p += loglikelihood[word]

    return p

# %%
logprior, loglikelihood = naive_bayes_train(freq, train_x, train_y)

# %%
my_tweet = 'She smiled.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is 1.557658105004371

# %%
my_tweet = 'He laughed.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is -0.16510849273673264

# %%
def test_naive_bayes(test_x, test_y, logprior, loglikelihood, naive_bayes_predict=naive_bayes_predict):
    #test the accuracy of prediction of the model
    y_hats = []

    for tweet in test_x:
        if naive_bayes_predict(tweet, logprior, loglikelihood) > 0:
            y_hat_i = 1
        else:
            y_hat_i = 0

        y_hats.append(y_hat_i)

    accuracy = np.mean(y_hats == test_y)

    return accuracy

# %%
print("Naive Bayes accuracy = %0.4f" %
      (test_naive_bayes(test_x, test_y, logprior, loglikelihood)))
# Out:
# Naive Bayes accuracy = 0.9955

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import ComplementNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report


# Combine the positive and negative tweets and create labels
tweets = positive_tweets + negative_tweets
labels = [1] * len(positive_tweets) + [0] * len(negative_tweets)

# Preprocess the tweets
processed_tweets = [' '.join(preprocess(tweet)) for tweet in tweets]

# Split the dataset into training and testing sets
train_x, test_x, train_y, test_y = train_test_split(processed_tweets, labels, test_size=0.2, random_state=42)

# Create a CountVectorizer to convert text data to numerical feature vectors
vectorizer = CountVectorizer()
train_vectors = vectorizer.fit_transform(train_x)
test_vectors = vectorizer.transform(test_x)

# Create a Complement Naive Bayes classifier
cnb_classifier = ComplementNB()

# Train the classifier
cnb_classifier.fit(train_vectors, train_y)

# Make predictions on the test set
predictions = cnb_classifier.predict(test_vectors)

# Evaluate the model
accuracy = accuracy_score(test_y, predictions)
print("Accuracy:", accuracy)

report = classification_report(test_y, predictions)
print("Classification Report:\n", report)



from sklearn.model_selection import GridSearchCV

# Create a MultinomialNB instance
catnb_classifier = ComplementNB()

# Define the hyperparameter grid to search
param_grid = {'alpha': [0.1, 0.5, 1.0, 2.0, 5.0, 6.5, 8, 10], 'fit_prior' : [True, False]}

# Create a GridSearchCV object with cross-validation
grid_search = GridSearchCV(catnb_classifier, param_grid, cv=5)

# Perform the grid search on your training data
grid_search.fit(train_vectors, train_y)

# Get the best hyperparameters
best_alpha = grid_search.best_params_['alpha']

# Train the final classifier with the best hyperparameters
final_classifier = ComplementNB(alpha=best_alpha)
final_classifier.fit(train_vectors, train_y)

# Make predictions on the test set using the final classifier
predictions = final_classifier.predict(test_vectors)

# Evaluate the model
accuracy = accuracy_score(test_y, predictions)
print("Accuracy:", accuracy)

report = classification_report(test_y, predictions)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.7405
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.77      0.74       988
#            1       0.76      0.71      0.74      1012
#
#     accuracy                           0.74      2000
#    macro avg       0.74      0.74      0.74      2000
# weighted avg       0.74      0.74      0.74      2000
#
# Accuracy: 0.742
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.77      0.75       988
#            1       0.76      0.72      0.74      1012
#
#     accuracy                           0.74      2000
#    macro avg       0.74      0.74      0.74      2000
# weighted avg       0.74      0.74      0.74      2000

# %%
grid_search.best_params_
# Out:
# {'alpha': 2.0, 'fit_prior': True}

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# Combine the positive and negative tweets and create labels
tweets = positive_tweets + negative_tweets
labels = [1] * len(positive_tweets) + [0] * len(negative_tweets)

# Preprocess the tweets
processed_tweets = [' '.join(preprocess(tweet)) for tweet in tweets]

print(processed_tweets)

# Split the dataset into training and testing sets
train_x, test_x, train_y, test_y = train_test_split(processed_tweets, labels, test_size=0.2, random_state=42)

# Create a CountVectorizer to convert text data to numerical feature vectors
vectorizer = CountVectorizer()
train_vectors = vectorizer.fit_transform(train_x).toarray()
test_vectors = vectorizer.transform(test_x).toarray()

# Create a Categorical Naive Bayes classifier
catnb_classifier =  MultinomialNB()

# Train the classifier
catnb_classifier.fit(train_vectors, train_y)

# Make predictions on the test set
predictions = catnb_classifier.predict(test_vectors)

# Evaluate the model
accuracy = accuracy_score(test_y, predictions)
print("Accuracy:", accuracy)

report = classification_report(test_y, predictions)
print("Classification Report:\n", report)





from sklearn.model_selection import GridSearchCV

# Create a MultinomialNB instance
catnb_classifier = MultinomialNB()

# Define the hyperparameter grid to search
param_grid = {'alpha': [0.1, 0.5, 1.0, 2.0, 5.0, 6.5, 8, 10], 'fit_prior' : [True, False]}

# Create a GridSearchCV object with cross-validation
grid_search = GridSearchCV(catnb_classifier, param_grid, cv=5)

# Perform the grid search on your training data
grid_search.fit(train_vectors, train_y)

# Get the best hyperparameters
best_alpha = grid_search.best_params_['alpha']

# Train the final classifier with the best hyperparameters
final_classifier = MultinomialNB(alpha=best_alpha)
final_classifier.fit(train_vectors, train_y)

# Make predictions on the test set using the final classifier
predictions = final_classifier.predict(test_vectors)

# Evaluate the model
accuracy = accuracy_score(test_y, predictions)
print("Accuracy:", accuracy)

report = classification_report(test_y, predictions)
print("Classification Report:\n", report)
# Out:
# ['followfriday top engag member commun week :)', 'hey jame odd :/ pleas call contact centr 02392441234 abl assist :) mani thank', 'listen last night :) bleed amaz track scotland', 'congrat :)', 'yeaaah yipppi accnt verifi rqst succeed got blue tick mark fb profil :) 15 day', 'one irresist :) flipkartfashionfriday', 'like keep love custom wait long hope enjoy happi friday lwwf :)', 'second thought ’ enough time dd :) new short enter system sheep must buy', 'jgh go bayan :d bye', 'act mischiev call etl layer in-hous wareh app katamari well … name impli :p', 'followfriday top influenc commun week :)', 'love big ... juici ... selfi :)', 'follow follow u back :)', "perfect alreadi know what' wait :)", 'great new opportun junior triathlet age 12 13 gatorad seri get entri :)', 'lay greet card rang print today love job :-)', "friend' lunch ... yummm :) nostalgia tb ku", "id conflict thank help :d here' screenshot work", 'hi liv :)', 'hello need know someth u fm twitter — sure thing :) dm x', 'followfriday top new follow commun week :)', "i'v heard four season pretti dope penthous obv gobigorgohom fun y'all :)", 'yeah suppos lol chat bit x :)', 'hello :) get youth job opportun follow', '💅🏽 💋 :) seen year', 'thank :-)', 'hope rest night goe quickli ... bed ... got music fix time dream :)', 'spiritu ritual festiv népal begin line-up :) left line-up see ...', "hey sarah send us email bitsy@bitdefender.com we'll help asap :)", 'lol :d', 'kik hatessuc 32429 kik kikm lgbt tinder nsfw akua cumshot :)', 'come hous :)', 'nsn_supplement effect press releas distribut result :) link remov pressreleas newsdistribut', 'hi bam follow bestfriend love lot :) see warsaw <3 love <3 x46', 'everyon watch documentari earthl youtub :-)', 'follow follow u back :)', 'followfriday top support commun week :)', 'buuut oh well :-)', 'look forward visit next week letsgetmessi jo :-)', 'make u feel better never see anyon kpop flesh :d', 'good girl best wish :-)', 'great enough reason listen one epic soundtrack :d', 'thank shout great friday :)', 'ad video playlist im back twitch today go leagu :) 1 4', 'would love see dear jordan :) wait :)', 'oh okay :d thank', 'like fake gameplay ;) haha im kid im kid good stuff :)', 'yeah exactli :)', 'new product line etsi shop check :) boxroomcraft', 'hope vacat go great :d', 'recharg normal come charger u buy :)', 'followfriday top engag member commun week :)', 'well asleep one talk sooo someon text :)', "ye suppos bet he'll blue fit hear speech today piti :-)", 'green garden midnight sun beauti canal dasvidaniya till next visit :)', 'scout sg futur wlan pro confer asia :)', 'good u better chang lollipop 🍭 :)', '<3 u nez :) agnezmo', 'follow pleas :) big dream :)', 'oley :d', 'mama reason stand stronger :)', 'follow follow u back :)', 'oh god misti babi cute :d', 'love blue :) flipkartfashionfriday', "woohoo can't wait :) sign yet still think mka", 'liam access :)', 'welcom :)', 'stat day arriv 1 new follow unfollow :) via', 'surpris ... amaz figur :)', 'followfriday top influenc commun week :)', 'happybirthdayemilybett :) wish best beauti sweet talent amaz …', '2 plan day drain great :)', 'gotta love timezon :p', 'parent proud — lol least :d mayb sometim get happi grade al ...', 'grand :)', 'manila_bro chosen follow twitter thank follow :)', 'sure let know around .. side world eh u take care :-)', 'followfriday top new follow commun week :)', 'final fuck weekend :)', 'real :)', 'thank :d', 'hi bam follow bestfriend love lot :) see warsaw <3 love <3 x45', 'ye join hushedcallwithfraydo call gift <3 gotta get :d', 'yeahhh :)', 'dm make night better :)', 'join hushedpinwithsammi event :d might get text day luv u', 'would realli appreci share video around :)', 'hello :) get youth job opportun follow', 'oh wow beauti tom :)', 'love :)', 'ad video playlist im back twitch today go leagu :) 1 3', 'followfriday top support commun week :)', 'follow follow u back :)', "gym monday can't wait :) like", "hey here' invit join scope influenc  ...
# Accuracy: 0.741
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.77      0.75       988
#            1       0.76      0.71      0.74      1012
#
#     accuracy                           0.74      2000
#    macro avg       0.74      0.74      0.74      2000
# weighted avg       0.74      0.74      0.74      2000
#
# Accuracy: 0.7425
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.77      0.75       988
#            1       0.76      0.72      0.74      1012
#
#     accuracy                           0.74      2000
#    macro avg       0.74      0.74      0.74      2000
# weighted avg       0.74      0.74      0.74      2000

# %%
grid_search.best_params_
# Out:
# {'alpha': 2.0, 'fit_prior': True}

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# Combine the positive and negative tweets and create labels
tweets = positive_tweets + negative_tweets
labels = [1] * len(positive_tweets) + [0] * len(negative_tweets)

# Preprocess the tweets
processed_tweets = [' '.join(preprocess(tweet)) for tweet in tweets]

print(processed_tweets)

# Split the dataset into training and testing sets
train_x, test_x, train_y, test_y = train_test_split(processed_tweets, labels, test_size=0.2, random_state=42)

# Create a CountVectorizer to convert text data to numerical feature vectors
vectorizer = CountVectorizer()
train_vectors = vectorizer.fit_transform(train_x).toarray()
test_vectors = vectorizer.transform(test_x).toarray()

# Create a Categorical Naive Bayes classifier
catnb_classifier =  BernoulliNB()

# Train the classifier
catnb_classifier.fit(train_vectors, train_y)

# Make predictions on the test set
predictions = catnb_classifier.predict(test_vectors)

# Evaluate the model
accuracy = accuracy_score(test_y, predictions)
print("Accuracy:", accuracy)

report = classification_report(test_y, predictions)
print("Classification Report:\n", report)
# Out:
# ['followfriday top engag member commun week :)', 'hey jame odd :/ pleas call contact centr 02392441234 abl assist :) mani thank', 'listen last night :) bleed amaz track scotland', 'congrat :)', 'yeaaah yipppi accnt verifi rqst succeed got blue tick mark fb profil :) 15 day', 'one irresist :) flipkartfashionfriday', 'like keep love custom wait long hope enjoy happi friday lwwf :)', 'second thought ’ enough time dd :) new short enter system sheep must buy', 'jgh go bayan :d bye', 'act mischiev call etl layer in-hous wareh app katamari well … name impli :p', 'followfriday top influenc commun week :)', 'love big ... juici ... selfi :)', 'follow follow u back :)', "perfect alreadi know what' wait :)", 'great new opportun junior triathlet age 12 13 gatorad seri get entri :)', 'lay greet card rang print today love job :-)', "friend' lunch ... yummm :) nostalgia tb ku", "id conflict thank help :d here' screenshot work", 'hi liv :)', 'hello need know someth u fm twitter — sure thing :) dm x', 'followfriday top new follow commun week :)', "i'v heard four season pretti dope penthous obv gobigorgohom fun y'all :)", 'yeah suppos lol chat bit x :)', 'hello :) get youth job opportun follow', '💅🏽 💋 :) seen year', 'thank :-)', 'hope rest night goe quickli ... bed ... got music fix time dream :)', 'spiritu ritual festiv népal begin line-up :) left line-up see ...', "hey sarah send us email bitsy@bitdefender.com we'll help asap :)", 'lol :d', 'kik hatessuc 32429 kik kikm lgbt tinder nsfw akua cumshot :)', 'come hous :)', 'nsn_supplement effect press releas distribut result :) link remov pressreleas newsdistribut', 'hi bam follow bestfriend love lot :) see warsaw <3 love <3 x46', 'everyon watch documentari earthl youtub :-)', 'follow follow u back :)', 'followfriday top support commun week :)', 'buuut oh well :-)', 'look forward visit next week letsgetmessi jo :-)', 'make u feel better never see anyon kpop flesh :d', 'good girl best wish :-)', 'great enough reason listen one epic soundtrack :d', 'thank shout great friday :)', 'ad video playlist im back twitch today go leagu :) 1 4', 'would love see dear jordan :) wait :)', 'oh okay :d thank', 'like fake gameplay ;) haha im kid im kid good stuff :)', 'yeah exactli :)', 'new product line etsi shop check :) boxroomcraft', 'hope vacat go great :d', 'recharg normal come charger u buy :)', 'followfriday top engag member commun week :)', 'well asleep one talk sooo someon text :)', "ye suppos bet he'll blue fit hear speech today piti :-)", 'green garden midnight sun beauti canal dasvidaniya till next visit :)', 'scout sg futur wlan pro confer asia :)', 'good u better chang lollipop 🍭 :)', '<3 u nez :) agnezmo', 'follow pleas :) big dream :)', 'oley :d', 'mama reason stand stronger :)', 'follow follow u back :)', 'oh god misti babi cute :d', 'love blue :) flipkartfashionfriday', "woohoo can't wait :) sign yet still think mka", 'liam access :)', 'welcom :)', 'stat day arriv 1 new follow unfollow :) via', 'surpris ... amaz figur :)', 'followfriday top influenc commun week :)', 'happybirthdayemilybett :) wish best beauti sweet talent amaz …', '2 plan day drain great :)', 'gotta love timezon :p', 'parent proud — lol least :d mayb sometim get happi grade al ...', 'grand :)', 'manila_bro chosen follow twitter thank follow :)', 'sure let know around .. side world eh u take care :-)', 'followfriday top new follow commun week :)', 'final fuck weekend :)', 'real :)', 'thank :d', 'hi bam follow bestfriend love lot :) see warsaw <3 love <3 x45', 'ye join hushedcallwithfraydo call gift <3 gotta get :d', 'yeahhh :)', 'dm make night better :)', 'join hushedpinwithsammi event :d might get text day luv u', 'would realli appreci share video around :)', 'hello :) get youth job opportun follow', 'oh wow beauti tom :)', 'love :)', 'ad video playlist im back twitch today go leagu :) 1 3', 'followfriday top support commun week :)', 'follow follow u back :)', "gym monday can't wait :) like", "hey here' invit join scope influenc  ...
# Accuracy: 0.738
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.77      0.74       988
#            1       0.76      0.70      0.73      1012
#
#     accuracy                           0.74      2000
#    macro avg       0.74      0.74      0.74      2000
# weighted avg       0.74      0.74      0.74      2000

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# Combine the positive and negative tweets and create labels
tweets = positive_tweets + negative_tweets
labels = [1] * len(positive_tweets) + [0] * len(negative_tweets)

# Preprocess the tweets
processed_tweets = [' '.join(preprocess(tweet)) for tweet in tweets]

print(processed_tweets)

# Split the dataset into training and testing sets
train_x, test_x, train_y, test_y = train_test_split(processed_tweets, labels, test_size=0.2, random_state=42)

# Create a CountVectorizer to convert text data to numerical feature vectors
vectorizer = CountVectorizer()
train_vectors = vectorizer.fit_transform(train_x).toarray()
test_vectors = vectorizer.transform(test_x).toarray()

# Create a Categorical Naive Bayes classifier
catnb_classifier =  GaussianNB()

# Train the classifier
catnb_classifier.fit(train_vectors, train_y)

# Make predictions on the test set
predictions = catnb_classifier.predict(test_vectors)

# Evaluate the model
accuracy = accuracy_score(test_y, predictions)
print("Accuracy:", accuracy)

report = classification_report(test_y, predictions)
print("Classification Report:\n", report)
# Out:
# ['followfriday top engag member commun week :)', 'hey jame odd :/ pleas call contact centr 02392441234 abl assist :) mani thank', 'listen last night :) bleed amaz track scotland', 'congrat :)', 'yeaaah yipppi accnt verifi rqst succeed got blue tick mark fb profil :) 15 day', 'one irresist :) flipkartfashionfriday', 'like keep love custom wait long hope enjoy happi friday lwwf :)', 'second thought ’ enough time dd :) new short enter system sheep must buy', 'jgh go bayan :d bye', 'act mischiev call etl layer in-hous wareh app katamari well … name impli :p', 'followfriday top influenc commun week :)', 'love big ... juici ... selfi :)', 'follow follow u back :)', "perfect alreadi know what' wait :)", 'great new opportun junior triathlet age 12 13 gatorad seri get entri :)', 'lay greet card rang print today love job :-)', "friend' lunch ... yummm :) nostalgia tb ku", "id conflict thank help :d here' screenshot work", 'hi liv :)', 'hello need know someth u fm twitter — sure thing :) dm x', 'followfriday top new follow commun week :)', "i'v heard four season pretti dope penthous obv gobigorgohom fun y'all :)", 'yeah suppos lol chat bit x :)', 'hello :) get youth job opportun follow', '💅🏽 💋 :) seen year', 'thank :-)', 'hope rest night goe quickli ... bed ... got music fix time dream :)', 'spiritu ritual festiv népal begin line-up :) left line-up see ...', "hey sarah send us email bitsy@bitdefender.com we'll help asap :)", 'lol :d', 'kik hatessuc 32429 kik kikm lgbt tinder nsfw akua cumshot :)', 'come hous :)', 'nsn_supplement effect press releas distribut result :) link remov pressreleas newsdistribut', 'hi bam follow bestfriend love lot :) see warsaw <3 love <3 x46', 'everyon watch documentari earthl youtub :-)', 'follow follow u back :)', 'followfriday top support commun week :)', 'buuut oh well :-)', 'look forward visit next week letsgetmessi jo :-)', 'make u feel better never see anyon kpop flesh :d', 'good girl best wish :-)', 'great enough reason listen one epic soundtrack :d', 'thank shout great friday :)', 'ad video playlist im back twitch today go leagu :) 1 4', 'would love see dear jordan :) wait :)', 'oh okay :d thank', 'like fake gameplay ;) haha im kid im kid good stuff :)', 'yeah exactli :)', 'new product line etsi shop check :) boxroomcraft', 'hope vacat go great :d', 'recharg normal come charger u buy :)', 'followfriday top engag member commun week :)', 'well asleep one talk sooo someon text :)', "ye suppos bet he'll blue fit hear speech today piti :-)", 'green garden midnight sun beauti canal dasvidaniya till next visit :)', 'scout sg futur wlan pro confer asia :)', 'good u better chang lollipop 🍭 :)', '<3 u nez :) agnezmo', 'follow pleas :) big dream :)', 'oley :d', 'mama reason stand stronger :)', 'follow follow u back :)', 'oh god misti babi cute :d', 'love blue :) flipkartfashionfriday', "woohoo can't wait :) sign yet still think mka", 'liam access :)', 'welcom :)', 'stat day arriv 1 new follow unfollow :) via', 'surpris ... amaz figur :)', 'followfriday top influenc commun week :)', 'happybirthdayemilybett :) wish best beauti sweet talent amaz …', '2 plan day drain great :)', 'gotta love timezon :p', 'parent proud — lol least :d mayb sometim get happi grade al ...', 'grand :)', 'manila_bro chosen follow twitter thank follow :)', 'sure let know around .. side world eh u take care :-)', 'followfriday top new follow commun week :)', 'final fuck weekend :)', 'real :)', 'thank :d', 'hi bam follow bestfriend love lot :) see warsaw <3 love <3 x45', 'ye join hushedcallwithfraydo call gift <3 gotta get :d', 'yeahhh :)', 'dm make night better :)', 'join hushedpinwithsammi event :d might get text day luv u', 'would realli appreci share video around :)', 'hello :) get youth job opportun follow', 'oh wow beauti tom :)', 'love :)', 'ad video playlist im back twitch today go leagu :) 1 3', 'followfriday top support commun week :)', 'follow follow u back :)', "gym monday can't wait :) like", "hey here' invit join scope influenc  ...
# Accuracy: 0.5995
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.86      0.68       988
#            1       0.72      0.34      0.46      1012
#
#     accuracy                           0.60      2000
#    macro avg       0.64      0.60      0.57      2000
# weighted avg       0.64      0.60      0.57      2000

# %%
import re

def remove_non_alphanumeric_except_space(input_list):
    result_list = []
    for item in input_list:
        # Using regex to remove non-alphanumeric characters except space
        cleaned_item = re.sub(r'[^a-zA-Z0-9\s]', '', item)
        result_list.append(cleaned_item)
    return result_list

output_list = remove_non_alphanumeric_except_space(train_x)
output_list
# Out:
# [' matt',
#  'good thank anyway ',
#  'bf mean ',
#  'zzz miss stop ',
#  'mean 3am australia ',
#  'fake text ',
#  'actual made cri disgust actual fuck im disgust iv seen poor peopl ',
#  'wer sorri googl play music current experienc error pleas tri minut ',
#  'good match 2nite boy let go comp high enjoy  vike t20blast',
#  'earth ',
#  'aww last semest ever  def catch sometim soon alway leav long',
#  'im like pretend ',
#  'know exactli want get paralyz anxieti sad lol ',
#  'traffic ',
#  ' well cooki better worth',
#  'eat rest well  tire ',
#  'shave hair  feel like gotta shave beard bit  nooop',
#  'awh   stay ',
#  'ye alway selfish fuck ',
#  ' listen radio   worri wacha niend onlin',
#  'never give best thing take time weh ',
#  'tri use twitter account caesarspalac socialreward say account meet requir  damn twitter ',
#  'hayst ',
#  'straight 7elw  least mesh beyt 3a2ad',
#  'wag hopia pleas  zayniscomingbackonjuli 26',
#  'best get littl ladi pj need go wallpap mom  realli cba today',
#  'morn ',
#  'senpai  look buttsex',
#  'kind true p actuallythough',
#  'fotoset reus seem like somebodi fun today d',
#  'there stun show garden rh tatton park show wonder design construct plant ',
#  'gonna good father ',
#  'cheer och hun  xxx',
#  'hello info possibl interest jonatha close join beti ',
#  'promot ',
#  'thank ',
#  'hello need 25 g2a code pl ',
#  'thank sweetest kindest comet ',
#  'what wrong ',
#  'add snapchat entlerbountli snapchat snapchat tinder dirtykik followback countrymus sexcam ',
#  'janjua friend ',
#  'yea want cozi warm bed back x thx dear may work day chill short ',
#  'recentlywebsit upgrad might see new pictur coolingtow soonthank showinginterest ',
#  'ask shed probabl stab  found 6 speed massag chair shiatsu set heat 50 less risk',
#  'one would awesom well either even d',
#  'yeah  got shit bag laugh face anxieti har har har think  how go chum weekend',
#  'aw fuck there dress bag floor dammit that realli loud ',
#  'start use mine week ago  long break',
#  'post vid ',
#  'sorri ',
#  'right right  alway good memori guess ',
#  'hello  love carter ',
#  'go miss belt sam smith daili car ride ',
#  'alway make thing better   ',
#  'dearli miss love sunshin ',
#  'via  realiti ',
#  'hahahaha intent turn away said someth turn that kiss ',
#  'fever final caught  geskenya obamainkenya magicalkenya  greatkenya allgoodthingsk',
#  'done yey ',
#  'leav alon ',
#  'fback ',
#  'yeah theyr give subtl hint also tip 2 use commun last year  prim  algorithm iii',
#  'help  stop cri ',
#  ' hubbi delight return home lol',
#  'earli ',
#  'yasss still dont get paid til august 6th  lol still got hella cloth though',
#  'hey mayb get pictur warmup gone sign session arriv ',
#  'headlin 2017 ',
#  'good morn ',
#  'today happi day ',
#  'well haha d',
#  'patient d korean netizen crueler thought',
#  'miss ',
#  'ohaha problem thank btw ',
#  'bad good parent also proud today bc guy thank x notic pleas ',
#  'victoria park book close ',
#  '',
#  ' face enough  face flesh know daft  cope ',
#  'fricken cold ',
#  'like fake gameplay  haha im kid im kid good stuff ',
#  'kik hatessuc 32429 kik kikm lgbt tinder nsfw akua cumshot ',
#  'iv friend steph mel longest time im actual sad havent met yet  want hug',
#  'helppp  im u want order refurbish cintiq companion onlin card origin outsid u',
#  'ohhh got p',
#  'classic man good start fri ',
#  'follow follow u back ',
#  ' sad want hair colour back ',
#  'happi birthday  jiva ever    ',
#  'srsli today like best day ever ',
#  'stat week arriv 1 new follow unfollow  via',
#  'lol well cant buy nacho ',
#  'new user ',
#  'there milk left cereal ',
#  'good go andr keep ',
#  'thank god friday  jgh',
#  'ill save ',
#  'good night ',
#  'hug mani ',
#  'worri let us know goe   aj',
#  'hungri ',
#  'wish go taylor swift ',
#  'chaerin unni',
#  'dont give know better day come ',
#  'thank retweet  make sure keep touch news light bulb made corn wast',
#  'unfortun  sorri',
#  'happier run around hous wear h shirt ',
#  'want harri dm bc wanna give surpris friend birthday wanna make happi ',
#  'add snapchat yall  give name',
#  'cant sleeep ',
#  'thank everett taylor follow appreci support sure like us facebook ',
#  ' pleas notic',
#  'hay ',
#  'ohmyg yaya dub im done stalk ig accnt  gondooo moo tologooo  haha',
#  'may brain tumor si vivian  mmsmalubhangsakit',
#  'wer isol fa p',
#  'follow thank pleas follow ',
#  'manag job tell friend two prettiest girl       ',
#  ' beauti',
#  'hate get text look shift everyone wake ',
#  'cheer ',
#  'yeey d',
#  'know ',
#  'good quit full time job last week cant find anoth one ',
#  'cricket world cup asian cup state origin  wow matt lucki boy  fun',
#  'pinter ',
#  'well bud guess im go bed goodnight guy see morn whatev woke ',
#  'iv eye small kate spade bag pero walang maganda ',
#  ' cat cafe melbourn',
#  'bout lay watch jurass world love littl movi night  ',
#  'realli love  love thing ',
#  'thank anu ',
#  'tri keep hous use buy truckload miss 13 favour ',
#  'birthday week today d',
#  'pleas went well wayn shame  x',
#  'u cant chang peopl feel u dnt tri live ur life happi ',
#  'sowwi  3000 word limit realli grind gear 0001 chanc win make',
#  'happi friday ',
#  ' im alreadi plan lfccw hope meet guest',
#  'could make foxy song version instrument form sound epic beat alon ',
#  'haha thank man  fingerscross  delv deep htaccess file',
#  'get well soon dan big hug ',
#  'never show much ',
#  'whaaat nooo ',
#  'nooo onlin u tweet fan ',
#  'ye far nightmar sort  light end tunnel fank dog xxx',
#  '    stay perfect girli',
#  'ff great weekend ',
#  'aw fuck suck ',
#  'got hack im sorri ',
#  'thank ',
#  'thank wer set anoth great day support commun help resid  servicewithasmil',
#  'thank screenshot po let take care spammer  proceed c ',
#  'hi enter purchas speciallymark first choic custard pack enter via sm onpack instruct  good luck',
#  'inde ',
#  'cant believ ill go work today wish ',
#  'chinua acheb intellectu doesnt mean know intellectu issu mean take pleasur ',
#  ' ffspecial acha banda hai  tweet bhi achi krta hai handsom bhi hai  must follow ',
#  'need rare sponsorship aswel sponsor gigi ',
#  'week 2  cant wait week 3 ',
#  'dont cri babi talk ',
#  'follow thank pleas follow ',
#  'loool oi  bengali gener insecur itll work',
#  'jimin fancaf post yesterday  gone',
#  'im alway never ever notic ',
#  'head kill today ',
#  'sorri ',
#  'nice ',
#  'told u guy bday today  gift want 5 paypal',
#  'snapchat jillcruz 18 snapchat kiksext likeforlik hornykik lgbt music camsex ',
#  'ok went check lucki she pass away  best magpi ever came across rip lucki 2205 1524 0515 x',
#  'oh barney ',
#  'awww thank  im still ugli huhu idk',
#  'yach  telat  huvvft  ',
#  'thank bhaiya ',
#  'pleas follow ',
#  'love miss hammi thank ',
#  'sure fing ',
#  'mean alreadi dream come true notic that enough ',
#  'talk help ',
#  'blog  excus problem attend via',
#  'happi bday awesom thank amaz felic smoak    ',
#  'earli bird gone alreadi da nice ',
#  'made realli angri sad   new biom ',
#  'ezoo year sorri ',
#  'love day ye stay happi  ',
#  'brief introduct 2 earliest histori indian subcontin even bfr maurya ',
#  'aww iv alreadi left would come said hey seen sooner  good night x',
#  'rofl shade grey netsec edit ',
#  'new mosquito bite ',
#  'readi weekend race track saturday dad work picnic sunday monday hock hill mamma ',
#  'isco ',
#  'mad gigi dream hang didnt want talk ',
#  'hit 10000 play girlfriend remix ',
#  'rib ',
#  'im look influenc app  interest here invit',
#  'pretti hair ',
#  'get jonghyun hyung  pleas predict ',
#  'okk den call abp n spread allov india n abroad well p',
#  'welcom hun  thank follow',
#  'truck week ago ',
#  'im workin  got day tuesday tho haha x',
#  'oh must annoy evan  text give option opt',
#  'secret ',
#  'kind thk ',
#  's2e12 probabl saddest ive ever felt rumpi ',
#  'oh sorri hear  pleas email inform proillamasquacom instead manual set x',
#  'ill around 10 train delay ',
#  'wish could pizza deliv 5am  ',
#  'thank favorit appreci ',
#  'follow thank pleas follow ',
#  'sad ',
#  'haha woke seen typo shoulda snark lession stupid drunk finger d',
#  'hi adrian parcel monday tuesday  pri',
#  'congradu gent  cc',
#  'lemm cover u lipstick n cran vodka ',
#  'nominier und ',
#  'fair enough ',
#  'follow follow u back ',
#  'hi ate ',
#  'kat offic client ',
#  'omg amber ',
#  'ye pleas would brighten night shift nomnomnom d chocol dukefreebiefriday xx',
#  'video sararoc angri world ',
#  'jumma kareem  friday remind recit surah kahaf ',
#  'im alreadi bad day ',
#  'la time right ye yunni im seriou ',
#  'd true',
#  'im still awak  feel like need delet 80 peopl snap',
#  'find quit cool unlock bemeapp  thumb 4 u beme figur bemecod proudtobem',
#  'happi belat birthday sweeti ',
#  'pictur ',
#  'look like weather go bit mix weekend sunshin rain wind cours prepar condit ',
#  'ahh wonder theyr realli support pg shame msc like ',
#  'free slice toast everi larg coffeeweekday 911 30  ask us offer ',
#  'miss geneva much england aint got half sun ',
#  'bright weather today hope london hot tommorow cant wait go tommorow d',
#  'oh okay d thank',
#  'hey girl mustb dairi produxt want cant lactos intoler ',
#  'goodnight liam hope fantast day today  sweet dream babi love heart d xx',
#  'look noth im bore ',
#  'ye omg lile tid tmi ',
#  'bulet gendut ',
#  'alreadi ',
#  'welcom kfcroleplay enjoy let friend ',
#  'follow stay updat ',
#  'aw that shame thought well miss ',
#  'thank mayb late sleep ',
#  'get mb need cut perf cut programm ',
#  'bra shady kiss though  isibaya',
#  'readi scorch srski  much tdc',
#  'reject reason peopl deni realli feel ',
#  'ingat din man godbless ',
#  '2nd thought colleg ',
#  'premiun featur make  notcool',
#  'everyon happi bc amaz friend bc 1d still wait internet bestfriend ',
#  'think mjhe aaj tak kisi ne dm ni kiya ',
#  'noo sad time  rubi replac shuffl act',
#  'lead caus cancer children five ',
#  'two dog one cat good friend  goodwynsgoodi freebiefriday',
#  'sooo pretti d',
#  'much doubt anyth chang seven news anytim soon either dream right ',
#  'thank  cjradacomateada',
#  'envi peopl get meet pictur laura taylor lana etc theyr lucki meet babi ',
#  'yepp cours mo ',
#  'lol selo ',
#  'iv go sleep like 5am everday  would cool peopl like would hangout time',
#  'happi birthday miss chenoweth hope great one  oodl cake ',
#  'tri think return spain leav eldest behind alreadi one cri ',
#  'thank jame stuck cocktail tri next definit recommend virgin redhead  j',
#  'aaahhh see  ',
#  'follow thank pleas follow ',
#  'that english namee  haiqal isnt english name rememb',
#  'here wish happi birthday doug bolling turn 34 today   play',
#  'hi everyon  good aftenoon feel booor  ',
#  'look forward hear thought  maritimen',
#  'god give us strength purpos help other struggl ',
#  'kept look bag ',
#  'good read ',
#  'yeah next prey  poor girl',
#  'west countri weekend next ride day tuesday  sunni weekend around',
#  'wait peopl call bigot p',
#  'make better though ',
#  'play witcher 3 two month exactli realli feel like go back wish id fallen love ',
#  'hey babe came across pic  cant read hindi ',
#  'happi birthday  pricelessantiqu takesonetoknowon ',
#  'happi friday  catch us 01282 452096 want chat ',
#  'final could stream ugh make home past day broadcast ',
#  'demand ',
#  'thank hope got good book keep compani ',
#  'gut never went distant world london im well long ',
#  'brilliant  said india innov  thank introduc ',
#  'supercar ice cream mani gurgaon locat  pl add locat',
#  'oh fact p',
#  'thank gen miss d',
#  'itti bitti teeni bikini ',
#  'look genad better price negoti  someon help  huhuhuhuhu bbmadeinmanila findavip',
#  'hell naw angi aint nobodi pay fuck though ',
#  'sleep would nice ',
#  'grandad realli well  worri much',
#  'spring fiesta 2015 make nois awuuu aich ',
#  '225 k noth asham dude start ',
#  'baggag claim final goodby new plane friend ',
#  'weekend gonna shoot love 3 pictur made last time d',
#  '2 month wait final hoodi  eeep yay sohappyrightnow',
#  'rain like cat dog  cant go anywher  water road everywher  ',
#  '1 year sinc text  miss everyth know never ',
#  'go stream soon ',
#  'still sad kick epic motherfuck ',
#  'end would leav work therefor miss ',
#  'sadli show masaan  watch muv come hd',
#  'fulfil fantasi    ',
#  'onlin pleas ',
#  'pleas ask upvot ',
#  'hyungwon beauti ',
#  'someon harri potter marathon ',
#  'love joy ',
#  'mistak happen man long get play game well happi ',
#  'toni stark  incred toni pictur',
#  'ew whose play fifa wow sound like good lineup ',
#  'themadstork follback ya ',
#  'hmm tweet antagonist liter sing ob song ',
#  'gail ',
#  'certainli ',
#  'full breakdown materi use thorin d time hunt materi work project',
#  'miss mani peopl ',
#  '2week exam ',
#  'cant sleep  someon talk',
#  'gotham sneak peek ',
#  'congratul well deserv wer buzz ',
#  'cool ',
#  'ob 11h v kino ',
#  'miss sophi ',
#  'bank credit depart bad enough anz gone extrem offshor absolut classic  gottolovebank',
#  '',
#  'welcom kfcroleplay enjoy let friend ',
#  'im sure pure coincid done noth play imac sinc appl music launch ',
#  'becom better atrack better ',
#  'sc ',
#  'noth much need grow ',
#  ' awesomee',
#  'cat forgotten hate ',
#  'way boy ',
#  'lil bro  es corner ',
#  'hah  thousand lie d',
#  'sheffield  miss mych',
#  'niall niwll niall niall ',
#  'ive read cute fluffi cs ff  miss babi ',
#  'taken ',
#  'followfriday top influenc commun week ',
#  'nice d',
#  ' alway',
#  'thank ',
#  'fresh news still imposs play ',
#  'short talk last day beach  via',
#  'there 5 hour till im prob gonna fall asleep ',
#  'woke feel incred sick idk caus drank starbuck 11 oclock last night reaction med ',
#  'kind word thank much much good cheltenham area ',
#  'yang retweet  d',
#  '      love much believ will follow pleas follow pleas justin  x15 330        ',
#  'sad new anim kingdom ',
#  'want takoyaki  teenchoic choiceinternationalartist superjunior',
#  'pain workout love pain impair get uggghhh dam fuck day shit get dun ',
#  'spent 5min tryna lock hse door without get key stuck noob nxt level ',
#  'sorri inact ',
#  'god plan us plan need plan time believ know faith ',
#  'like moment  ',
#  'blog post hunger game mockingjay part 2 2015  teaser  thehungergam',
#  'okay ',
#  'feel bad helmi ',
#  'think itll sam would love he made biggest improv start ',
#  'anoth jumpsuit  bt denim   flipkartfashionfriday',
#  'theyr except two kill peopl ene',
#  'ek  want ff',
#  'relat sweet n sour kind bipolar peopl life  cuz life  full  ',
#  'mind follback ',
#  'teenchoic choiceinternationalartist superjunior ',
#  'he nice person idk anybodi would say ',
#  'safe d',
#  'listen  buddi  u wanna play like ',
#  'yeah shogi took  blameshoghicp',
#  'aww love kind men ',
#  'visit blog thank d',
#  'cant watch hxh place besid youtub vid like top 10 badass killua scene  im suffer',
#  'everyon follow ',
#  'cough awak ',
#  'want get uber ice cream area ',
#  'thank  tricki bt v import subject',
#  'inshaallah  wil  ',
#  'yippee hope littl one enjoy scrummi recip ',
#  'good reason hope ',
#  'fun boy d',
#  'marvel thwart ',
#  'meh rito pl someth ',
#  'mm okay thank ',
#  'pleas ask upvot ',
#  'thankyou bro ',
#  'especi like  cant song ',
#  'hi bam follow bestfriend love lot  see warsaw 3 love 3 x45',
#  'thank share articl ',
#  'want cebu lechon ',
#  'rememb unlist one hickey ',
#  'stream twitch join d',
#  'harana  wish could chanc sing song ',
#  'airport pictur jongda hardli see tlist ',
#  'happi birthday best wish dresden germani  love 3 3 3 3 pleas share',
#  'lose ',
#  'cri nth time today  kinda tire tho hay gonna life',
#  'thank ',
#  'truli later move know queen bee upward bound movingonup',
#  'die movi ',
#  'also know tweet ',
#  'hahaha u seriou himmat karain aur moo pay baat karain  u believ meri debat abu k cousin k sath hoteemi uncl ',
#  'id rather stay sleep weekend go ',
#  'miss mom ',
#  'parti promot ',
#  'like best brother ever  sosweet wsalelov',
#  'keep ask show kinick miss next time see beat extra hard pleas kind u ',
#  'oh yeah milo aurini juicebro fuck pillar respect commun d',
#  'one day ',
#  'hi jack best thing would call 101 ',
#  'want ft arianna ',
#  'wer sorri feel way shell  regularli review price offer best',
#  'wednesday need hurri ',
#  'still realli realli realli realli realli like chipotl chickfila stole heart ',
#  'hehe cool ',
#  'offer mixtap talk suckmejimin',
#  'feel drain like omg like tire physic mental haizzz eye still hurt urghhh sat sun cant even stay home ',
#  'thank ga d',
#  'couldv join pz earlier didnt wait  ',
#  'awww love trend doubt  akshaymostlovedsuperstarev',
#  'trust back ',
#  'like ',
#  'damn forgot hot chocol ',
#  'hate hot weather  graduat ceremoni later boy gonna wear suit everyon go die',
#  'good caus id like upload ',
#  'oh get second quot tweet mayb could pleas loui dm  pleas',
#  'followfriday top new follow commun week ',
#  '',
#  'cretaperfect 4me cretaperfectsuv creta load heart day mani heart ',
#  'btw honeymoon ',
#  'alway  posit',
#  'think im sick ',
#  'fine ',
#  'morn ',
#  'thankyou x ',
#  'listen life later ',
#  'tfw boyfriend  lol jest cook relax im sure ill eat lunch tomorrow',
#  'cant find book keep sane ',
#  'home dormtel near st scho girl siya tho  want help find onee',
#  'morn work unfortun  gdce gamescom',
#  'im join right d',
#  'beer love ',
#  'facad democraci drop quickli ',
#  'awesom d',
#  'casilla  manchest citi vs real madrid start xi rmtour 2015',
#  'great weekend friend ',
#  'live fam bam cough ',
#  'last day ',
#  'appar get internet monday guy new video go tomorrow anyway ',
#  'liam access ',
#  'indiankultur  oppos   happi anniversari ',
#  'much new music cant record yet coz voic gone  frustrat',
#  'want panem end  love book movi',
#  'pleas go check awesom friend stream he fantast artist ',
#  'tri get ice cream leed keep cancel  needicecreamnow ubericecream',
#  'happi friday everyon  big followfriday',
#  'weather aw today mean stuck ',
#  'today far spent tri read email without get distract dayofarch tweet far iv fail ',
#  'could  drive pass advert everyday go work determin roseburi familyhom',
#  'good afternoon ',
#  'iv type wors thing good p',
#  'hi could find way contact appl shuffl work play one song ',
#  'ourdaughtersourprid mani mani congratul papa ji ',
#  'love stuff need repeat relentlessli approxim next 5 year ',
#  'excit forget tag us soon get hand new window 10 pc  mm',
#  'im tell  shaa allah na forc chang phone mana ',
#  'child traffick get dare day howev spell get wors ',
#  'eye checkup ',
#  'cast vote next elect  jcreport',
#  'look amaz think saw meadowhal day actual unfortun weekend ill work ',
#  'lol 45 day ye kaslkdja final week ',
#  'happi friday ',
#  'dont want come home ',
#  'oh masa  got btw entrepreneurship empow',
#  'thakyou sir ',
#  'boy snapchattimg happi bc friend ruin said wanna fun   ',
#  'crazyyi thooo zz airport straight away soundcheck concert ',
#  'ugh im excit made ',
#  ' hug',
#  'fback ',
#  'belat happi bday sauc ',
#  ' hope work  better way',
#  'ihhh stackar ',
#  'ofc allow fan manag take pict  risk caught secur got kick ',
#  '3 guy ',
#  '       thank alway put smile face mind follow  nice day x 1710',
#  'stream pixel ',
#  'gimm european date ',
#  'want chocol lucozad     ',
#  'parent proud  lol least d mayb sometim get happi grade al ',
#  'one look like need much care studi ill favourit later ',
#  'excit chalkhil park celebr tomorrow midday come join fun ',
#  'awww babi ylona  awww dream team',
#  'omg  gonna happen yeah wish ',
#  'info yet well announc soon get filbarbarian ',
#  'wer allow cheat meal ',
#  'miss baao ',
#  'need big cuddl lew kiss face  want go',
#  'eish ive quit know  lost twitter mojo shame  n dont know get back  mara im sure help neh',
#  'hi bam follow bestfriend love lot  see warsaw 3 love 3 x43',
#  'okay theyr even d goodnight',
#  'hulk hogan news racial tirad  thought couldnt stoop lower role thunder paradis',
#  'follow back pleass ',
#  'work keep smile ',
#  'lol whole famili threaten daili basi d',
#  'whaaat    leav',
#  'love u ',
#  'ps3 still good id say keep use keep though choic ',
#  'wanna meet boy ',
#  'awww shit net low ',
#  '   meooowww wolf wolf wolf barkkkiiidee bark',
#  'good morn look forward see soon good day ',
#  'happi belat birthday cikaaa  wish best  maaf telat ngucapinnya d',
#  'morn  judith answer district council relat question today ',
#  '  heiyo visit websit free 50000 coin 8 ball pool thank d',
#  'guess never realli identifi pharmaci  verylaterealis iwishiknewbett',
#  'thank million keep eye tweet alway appreci ',
#  'darlen followback pleas ',
#  'sunburn peel ',
#  'great day silverston today beauti classic car bonu d',
#  'guy add kik sprevelink 633 kik hornykik chat porno orgasm free webcamsex ',
#  'realli think im gonna get one kindl paperwhite pay realli want start read want laserlik focu ',
#  'welcom twitter world agaaain sir ',
#  'cant date someon white sorri yo grandpa prolli wanna burn ',
#  'ahh thank much  xxx',
#  'follow ',
#  'googl made realli sad becom prime minist p',
#  'hello  get youth job opportun follow',
#  'wer glad discov us  let us know question',
#  'download ',
#  'welsh wale today yippe ',
#  'that 360hr summer end  huhuhu miss picc lot ',
#  'follow ',
#  'serious that amaz jealou never first fan  haha',
#  'welcom aw  go back next month rn tryna get healthi',
#  'wahahaah p',
#  'sleep pill iv nocturn past coupl day ',
#  'that differ depart d 1 benefit b2b vs b2c someon else money soo funni enterprison idea',
#  'u start compar religion rant well  ur student guess last bencher probabl 15',
#  ' pleas notic z',
#  'saran drama genr romanc comedi ',
#  'ouch slip disc sore today bring thw swim chute ',
#  'cute  ',
#  'good morn twitter friend hope amaz day freakin tire need sleep ',
#  'fback ',
#  'iv support sinc audit american idol  ugh still notic ',
#  '       thank alway put smile face mind follow  nice day x 1709',
#  'hungri ',
#  'ff keep busi  xx',
#  'kinda smug know stuff marrickvil public ten year ago ',
#  'knee replac get day  ouch',
#  ' hope enjoy',
#  'realli miss ',
#  'pretti ',
#  'thank ',
#  ' got ground bc think sneak peopl',
#  'happi birthday pleas come back singapor                  ',
#  'im get  wer least speak',
#  'feel like im person ireland go see croke park ',
#  'yep id without ning recommend book thought wow  think gener posit lead',
#  'titl say d',
#  'u older ',
#  'thank someon mayb look case 14518344 61 fast total fuck mad expens ',
#  'yeah saw tweet complet agre wer move quick enough transfer though ',
#  'princ charm stage  x',
#  'photoset sadomasochistsparadis wynter bottom outtak  sadomasochist  paradis cuti',
#  'allow mosquito bite ',
#  'turn cant handl critiqu  that mind ',
#  'think she busi ',
#  'never enough sleep ',
#  'least friday d',
#  'nice enji  good job ',
#  'mean offer ',
#  'aw  depend defin success good music success 2 id say success',
#  'hahaha hope  p',
#  'film day invit reason lol ',
#  'hiya tell amazon fire phone still avail cant find web site ',
#  '  face everi guy pull get head feel bae teeth dick ',
#  'cant tomorrow naw  eat share huhu',
#  'enjoy cute babi panda ',
#  ' xx',
#  'longer like toast ',
#  '9am tearout selekt yoot ',
#  'need sleep cuz anoth meet work morn ',
#  'thank ',
#  'turkey bomb isi syria allow usa use one airfield jet ',
#  '      love much believ will follow pleas follow pleas justin  x15 339        ',
#  'thought mad bank paypal yesterday royal fuck im screw ',
#  'nice one d',
#  'twa great thank ',
#  'publiliu syru fear death dread death ',
#  'carolin carolin guy say mighti fine  threw littl make  hbd  ',
#  'yum feed 6 leftov ',
#  'would anyway ',
#  'sorri pooo ',
#  'honestli blast get shitfac chat kind soul donat 70 tonight sing disney song d',
#  'rain need go away ',
#  ' im feel lone wth',
#  'u like uta read manga  love even  haha yeah',
#  'tope ',
#  'thank alway share love matt  brave weather weekend',
#  'song freak saaad ',
#  'pain tummi back keep wake  liter cant get comfort',
#  'sign ',
#  'send sunshin rain much ',
#  'miss ',
#  'haha 1017 d',
#  'miss hair colour ',
#  'go bed ',
#  'awhhh ok ok  see nalang class open hehe',
#  'owww choo chweet  love u ',
#  'thought ear malfunct thank good clear one apolog ',
#  'hi juli im sorri feel way  what happen laura',
#  'exactli  mauliat ito',
#  'chick ',
#  'know live australia talk friend cuz like 4am thank anyway ',
#  'weather app say rain tonight tomorrow  sit car watch footi',
#  'wer train socent startup week w wed love drop your arnd town ',
#  'teen top actual perform rain yesterday  fk ok  im still v proud la',
#  'omg whay ur di ',
#  'spotifi final figur im us let listen anymor ',
#  'rain rain go away ',
#  'thank retweet judi ',
#  'wanna watch movi ',
#  'thank ',
#  'self esteem lowest ',
#  'want fuck day collar ',
#  'pick pleas employ ',
#  'updat latest episod youtub due 1st song choic  problem view ur phone youtube2gpctsojkw',
#  'okay   ',
#  'get parti shoe readi 8 day go till next keep calm jump parti  special parti ticket ',
#  'life smile ',
#  'follow follow u back ',
#  'wait fuck ffvi  ugh',
#  'sorri nic dont ya worri surrend ',
#  'hi john pleas call 33 1 64 74 40 00 go citi hall know someon found ted love day ',
#  'happi bday queen cant wait see fav girl season  real inspir ili',
#  'iran irand  usiran nuclear deal mit expert size deal sever li  uniteblu tcot',
#  'chocol peanut  ',
#  'back thnx god im happi ',
#  'love lil babi ',
#  'im swipe right dont see anyth ',
#  'happi birthday buddi d',
#  'someth sad bad alway happen around time day everi year ',
#  'worri fix ',
#  'fback ',
#  'would love win deo faaabul d freebiefriday aluminiumfre stayfresh xx',
#  'trust without us ugli without u ',
#  'break heart caus im hard ',
#  'one last long lol block alreadi must nice tweet hate ',
#  'that awesom peopl take much longer ',
#  'god   ',
#  'friday give us call today commerci farm insur requir  happyfriday lookfortheo',
#  'thank follow ',
#  'oh  hope love time though danni',
#  'enough whit      stop',
#  'matchi matchi elsa hair  love u soo much',
#  'shop fun ',
#  'said id fall asleep earli today  yesterday im realli hungri ',
#  'ahahah consid petit love hate relationship height ',
#  'okay miss ',
#  'oh cours gain weight bcu use rubbish veggi iv learn balanc everyth ',
#  'follow pleas olli ',
#  'well made 13 week nwb offici today d wait till monday start long road walk',
#  'sweat look omg ',
#  'busi product day fill tear hour hour laughter today good day ',
#  'anyon else show box work     ',
#  'real ',
#  'right back excel job difficult medium ',
#  'one day  ',
#  'bad day ',
#  'one friend follow littl heart attack im sorri your block  sadi',
#  'appreci glad friend ',
#  '   happi birthday let joy never end d',
#  'pleas ',
#  'feel nose pool water goe ',
#  'peopl anyth postiv say keep opinion  look good strong alway',
#  'u follow back  huehu',
#  'thank nice final see end work nearli  ',
#  'isi chan d',
#  '',
#  'zayn pleas follow would mean world birthday d love much amaz 3',
#  'im annoy ',
#  'want healthi happi know he gonna make ',
#  'fuck slay ',
#  'spoil ',
#  'welcom  nairobi hrdstellobama region civil societi dialogu human right region',
#  'surpris  amaz figur ',
#  'ah sokay andi thank youand ',
#  'new product line etsi shop check  boxroomcraft',
#  'she nice girl trust   okok trust u 3 33',
#  'keeo guess what behind white cover  special  happi bday darl ',
#  ' except lord mashaallah ',
#  ' that best one   ',
#  'thaank jhezz omg stay awesom damn sneak ',
#  'chalut ',
#  'thank fill although opinion still stand agre disagre harm done ',
#  'hey tweep join flipkartfashionfriday folow win 2k ',
#  'happend kian  okay',
#  '2 dollar    ',
#  'listen live   ',
#  'far away ',
#  'hope get lot nice gift d',
#  'appreci recent retweet great friday ',
#  'great enough reason listen one epic soundtrack d',
#  'goodby forget feminist fought right act like snobbi littl bitch  goodnight',
#  'pleas pray friend bilal ashraf icu ',
#  'rage quit ',
#  'good thing ',
#  'ye ',
#  'final get bed  good night tweeti',
#  'iv run bread feel well enough make ',
#  'place forev hold special place heart    gonna miss germani ',
#  'im bright man ',
#  ' exam soon sighsss',
#  'call savag god p',
#  'grabe ang harsh huhuhu u like ',
#  'hoya mah alway good look  comment a ',
#  'follow follow u back ',
#  'valentin et al 2009 found relationship homo biphob comment certain disciplin incl european languag lit educ ',
#  'ha chainsaw p',
#  'nobodi care optimis ',
#  'gotten sleep 3 12 hour ',
#  'wish could mayb one year ',
#  'think could get sponsor ',
#  'oh  hope everyth okay',
#  'followfriday top influenc commun week ',
#  'enjoy hope weather hold guy ',
#  'look rather fanci right ',
#  'ok whole time iv toss turn bed tri go sleep cant ',
#  'unfollow pleas follow  colombia love',
#  'read sm quot fb remind abt sm 1 miss much ',
#  'manag 1 month account  tax credit deadlin 31 st get child tax credit cut oct',
#  'oop well least theyll realis doesnt work anymor ',
#  'wish went vidcon ',
#  'yea drive peopl ',
#  'thank mate much appreci ',
#  'morn  friday happi friday beauti peopl  smile',
#  'im jealou alway plan go togeth ',
#  'yeheyi thank much pinya  whoooah win',
#  'let friend ',
#  'forgot headphon shit cunt  listen everyon room breath',
#  'old one day  ',
#  'well im p 41 8 page note thu far  iv read twice',
#  'get sick ',
#  'look old photo get sad ',
#  'tri xbox seem work   itd make killer background',
#  'wifi steroid today d',
#  'think everyon ',
#  'mommy manila iv seen ',
#  'text ',
#  'misss uh yr  cnt wait c uh    ',
#  'ao want stick 8th either ',
#  'unfollow unni ',
#  'amb pleas harry jean    ',
#  'elmhurst fc  ill alway etid',
#  'day dozen parent children kill babi shark selfi ',
#  'ehem   haha ala yeke  okay fun kk jumpa next time    mayb ',
#  'happiest birthday hope wonder day ',
#  'unniee ',
#  'unlik ',
#  'nawe ',
#  'greatli appreci ',
#  '  want ff',
#  'he ador like cute marshmallow u wanna hug eat bc cute chswiyfxcskcalum love much ',
#  'give chill ',
#  'oh allow vote teen choic award  said im area',
#  'shiiit  sorri',
#  'thank retweet ',
#  'fuuuck ',
#  'project want enter pitchwar may work  first chap mine phone call transcript ugh',
#  'yeah ',
#  'visit blog thank d',
#  'one bottom look like boob ',
#  ' flawless remix',
#  'send free organ coffe ',
#  'hi made chang design hope like ',
#  'alway nice get invit ',
#  'a9 would ice cream without ice  wsalelov',
#  'cuti ',
#  'stat day arriv 1 new follow unfollow  via',
#  'see brighton last year wed anniversari year birthday time impecc ',
#  'thank much  ff',
#  'blog stori institut im franc ',
#  'happi friday everyon hope fantast week  friday',
#  'biodivers taxonom infrastructur intern collabor new speci discoveri suppl data pdf ',
#  'soon tweet plant claw thigh traction zoom away ',
#  'ehdar pegea panga dosto  open link nd read news',
#  'hello  play yello race',
#  'wait foundri ',
#  'connect leav compani alert ',
#  'sorri antagonis call writer sever polit nudg  ',
#  'wanna watch paper town ',
#  'beleaf u ',
#  'ye cours love talk volunt mayb even time get job ',
#  'ah dude ',
#  'listen radio ',
#  'huge warm welcom   final complet triangl ',
#  'thank ',
#  ' pleas make one miss fabian',
#  'lol happi friday peep d',
#  'buset ',
#  'welcom version twitter hell ',
#  'pip post think ',
#  'thank ',
#  'yeah  appear work want free cornetto  strawberri one  fake cornetto',
#  'hi sorri alreadi shawn mend sponsor ',
#  'im find one day alreadi hope get better quickli ',
#  'happybirthdayemilybett  wish best beauti sweet talent amaz ',
#  'happyyi birthdaaayyy ',
#  'follow follow u back ',
#  'keep smile  perhap smile renew hope someon who lose   smile chariti ',
#  'hope wrong hulkhogan think know deep hurt wake kind unpleas ',
#  'mention south africa mani time song time come south africa ',
#  'guy add kik peli 829 kik kikmenow fuck model amateur elfindelmundo sextaatequemfimseguesdvcomvalentino ',
#  'leav pcb ',
#  'sorri god ',
#  'direct attent  awesomeo ',
#  'birthday today birthday wish hope there good news ben soon ',
#  'thought wer suppos hangout di week ',
#  'well steel next wednesday see like ',
#  'yeah true fuck one signatur dish last night unfamiliar kitchen ',
#  'let go  ill drive p travel travel yogyakarta jeep indonesia instamood ',
#  'last night good     ',
#  '3 good nigth  estoy escuchando enemi god',
#  'point yolo sort die lactos  ugh like 3 month pregnant bloat ',
#  'smile like mean  segalakatakata',
#  'summer dragon talk project repres slovenia  slovenia nba basketbal',
#  'never remov minion car 23 day run batteri banana ',
#  'thank take time repli albeit disappoint answer famou athlet race odd ',
#  'pleas tell ',
#  'jamesyammouni bet 20 follow   chelni   disappoint ',
#  'goodnight love luke heart  love ',
#  'sold ',
#  'geer bat mz yang deennya jehwan ',
#  'keep eye peel soon christina sign newslett offer go first ',
#  'idk went wrong use cute  kinda',
#  'caaannnttt ',
#  'basic nutshel  taken  letshavecocktailsafternuclai ',
#  'thought ',
#  'sunggyu plaster elbow  fall ',
#  'onkey nice edit lol sexi umma pervert onyu appa kid d',
#  'hi would like concert let know citi countri ill start work thank ',
#  'followback beauti girl today ',
#  'want froze chocol cover banana ',
#  'juli 24 2015 0115 mean time give love mist 45gameplay  ilovey',
#  'yeah tri look x ',
#  'aaaahhh man track traffic stress reliev ',
#  'omg miss ',
#  'ok  w hahaahahahaha',
#  'man got lucki charm ',
#  'wherev ill alway make smile ',
#  'peopl still code languag  right java guy php notion refer equal confus',
#  'whyd program acorn origin way sinc c64 apart cpu consider advanc ',
#  'yep expert bisexu  good luck',
#  'realli miss ',
#  'hi bam follow bestfriend love lot  see warsaw 3 love 3 x24',
#  'sometim sometim drown half bottl nyquil throat effect ',
#  'want back ',
#  'made final design pleas check ',
#  'second well done ',
#  'also want info ditch ill die vote tori  ',
#  'someth get friday great start  great day mclaren fridayfeel tgif',
#  'look like great way spend friday afternoon enjoy marathon iflix ',
#  'miss cat ',
#  ' yep  proud troll  ',
#  'hi bam follow bestfriend love lot  see warsaw 3 love 3 x8',
#  'love giveaway  freebiefriday',
#  'visit blog thank d',
#  'starsquad  pleas get follow awesom ',
#  'cat destroy back heel claw ',
#  'stat day arriv 2 new follow unfollow  via',
#  'oppa  hug ur arm like ',
#  'wish nice booti ',
#  'inter offer nemanja vidic roma  want either ',
#  'everytim look clock 302 someth weird happen finish cough blood start 302 nice ',
#  'hey lot write deathli hallow supernatur go ',
#  'hi bam follow bestfriend love lot  see warsaw 3 love 3 x10',
#  'love wakeup besid real dirti dirti sex ',
#  'ha love pic clearli much learn popular english pastim ',
#  'next oh yeah sharyl current got shane ta call ',
#  'imran khan hero  realli ikprideofpak',
#  'hey thank follow ',
#  'babi look good black ',
#  'absolut gut jame bay ticket sold manchest ',
#  'guy nooo  wow wow wow wow',
#  'skype account order think hack contact im sorri  im creat new one soon',
#  'kyunk aitchison hai p look respons origin tweet know brother',
#  'goosnight everyon love u ',
#  'dead d',
#  'kindli check email wer done send invoic sinc kanina pong umaga ',
#  'spotifi save day traffic ',
#  'get uca email today cant even get onto track 3 day ',
#  'feel stupid cant seem grasp basic digit paint noth iv research help ',
#  'serious want go back ',
#  'd d iv alway like larg let ',
#  'first item edit list ',
#  'normal get data usag warn til end month got today tweet ',
#  'cheer  caus haha mayb might let one day  thank kindli',
#  'like hurt feel anyth right ',
#  'stat day arriv 1 new follow unfollow  via',
#  'hi hope great time full happi  love  80x',
#  'would want peopl understand busi daili schedul  cmon guy bare even get 5 hour sleep ',
#  'ah sachin bring unimport stuff like context dampen excit ',
#  'good u better chang lollipop  ',
#  'profession hit video wick boomshot fuh di world even thank ',
#  'ff even know  time',
#  'ap anymor ',
#  'volunt one p',
#  'even know what go  fill pleas soon babe      xoxoxo',
#  'guy want dick pic want meaning convers thing common ',
#  'septemb yet need ouat back ',
#  'mb need coffe ',
#  'oop got day muddl ill tomorrow ',
#  ' sad',
#  'love ',
#  'ahhh u see u wake ',
#  'alreadi knew stand let peopl dislik  burdensom want total clear soon possibl',
#  'stargat atlanti cool show ',
#  'today  job anoth fack intel extra mega care get bent socket pin  pcgame pcupgrad',
#  'thank ',
#  'long wait  otwolgrandtrail',
#  'swifti outsid u suppos vote  realli realli realli want help win',
#  'idk p follow  ',
#  'want jack follow bad want annoy spam  sooo follow pleas  ',
#  'junjou junjou romantica ',
#  'follow thank pleas follow ',
#  '7th cinepambata video festiv complet mechan offici entri form may download sali na d',
#  'burnout d johnforceo ceo 1month',
#  'cheer ',
#  'look ',
#  'a4 would love gift si blue kurta blue fav color  wsalelov',
#  'mayb tweet ',
#  'alex fell asleep ',
#  'follow follow u back ',
#  'twine look great diane place ',
#  'french fan made movi wwat franc last year video photo ',
#  'thank mention cours ',
#  'understand  sad depress make extrem anxiou poc ',
#  'celebr end work week  invit friend dine experi modern korean hous ',
#  ' sad us wer loser',
#  'athabasca glacier 1948  athabasca glacier jasper jaspernationalpark alberta explorealberta ',
#  'car suspems cant cope offroad adventur there harvest machineri left inapropri place weav around ',
#  'ruin fridayfeel know next day wake earli morn  ',
#  'probabl find funni 222 ',
#  'need clean window point today bc hugh keep paw leav muddi mark everywher ',
#  'kafi din bad mene aj koi post share ki friend like rewert bunta warnaaa  ',
#  'look made final design hope like ',
#  'fuck hate wake like time cant fall back asleep ugh ',
#  'rest day ',
#  ' make sad',
#  'bc feel creepi today pmsl mianh milkeu ',
#  'miss cr feel like go back cant ',
#  'd love lot  xx',
#  'friend ',
#  'famili time d dj resto ',
#  'hand incorrect spell im apologist d',
#  'sorri sorri ',
#  'cant open  stockholm',
#  'live stream suck ',
#  'watch cop  jame',
#  'ugh well could still say im lucki sapiosexu ',
#  'dont trade trade harri sorri one ',
#  'taylor crop ',
#  'even real word d',
#  'true stay beauti ',
#  'plisss tweet elf  teenchoic choiceinternationalartist superjunior',
#  'thank love ff right back love day ',
#  'bad d chanhun alreadi individu photoshoot afteral',
#  'want dm justin let know ill gladli give ',
#  'ye sirkay wali pyaaz daal made daal got onion vinegar ',
#  'hay idk babi    ',
#  'best photobomb d pic ',
#  'nk gi uss birthday ',
#  'hug ang kiss philippin ',
#  'wsalelov an 9 depress would ',
#  'boohoo back work tonight anoth weekend night   ',
#  'band great thank come love see ',
#  'aw wanna go see dolphin  cute xxx',
#  'followfriday top influenc commun week ',
#  'wish ',
#  'wake d 50notif',
#  'wait noth ',
#  'hope like  jabongatpumaurbanstamped hope notic effort d',
#  'feel girl ',
#  'follow thank pleas follow ',
#  'im glad like servic happi shop us  dv',
#  'woah big plan good luck ',
#  'wanna watch paper town sadli one go w ',
#  'sure ',
#  ...]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

def generate_word_cloud(sentences, name):
    text = " ".join(sentences)
    wordcloud = WordCloud(width=800, height=800, background_color="white").generate(text)
    plt.figure(figsize=(10, 10))
    plt.title(name)
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()


def generate_bar_graph(sentences):
    text = " ".join(sentences)
    words = re.findall(r'\b\w+\b', text.lower())  # Extract all words
    words_filtered = [word for word in words if len(word) >= 3]  # Filter words with 3 or more characters
    word_freq = Counter(words_filtered)  # Count word frequencies

    top_words = word_freq.most_common(15)  # Get top 10 words
    top_words, word_counts = zip(*top_words)

    plt.figure(figsize=(10, 6))
    plt.bar(top_words, word_counts)
    
    plt.xlabel("Words")
    plt.ylabel("Frequency")
    plt.title("Top 15 Words with 3 or More Characters")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()



generate_word_cloud(output_list, "WordCloud for Train Dataset")
generate_bar_graph(output_list)

# %%
output_list_x = remove_non_alphanumeric_except_space(test_x)
output_list_x
# Out:
# ['love feel emm think ',
#  'thank guy ',
#  'love lord better life  3',
#  'yeah better use offici account  like  ',
#  'ok good night wish troy ugli met today   ok today fun im excit tmrw',
#  'im surpris sound hellish would thing ',
#  'dri hot scorch summer ff ',
#  'sad pray ',
#  'popol day ',
#  'song week ducktail surreal exposur sotw jingli jangli loveli ',
#  'interest speak ever ',
#  'lmfao serious cant rememb honestli  like tho ',
#  'taken pic mr wong confisc art work ',
#  'aarww  wish could  xx',
#  'see go  ye subject pain may real make less pain',
#  'genuin keep nightmar result day fam ',
#  'realli dont love much ',
#  'hit thumb ',
#  'noth shepherd bush either  want ice cream',
#  'unfortun ye ',
#  'oh realli  saw gif post seen realli happi mayb peopl whod happi naruhina',
#  'beyond word sooo freak good im go die come d',
#  'famili hang   feel festiv jamuna futur park',
#  'cream pinay pie soup ',
#  'favorit tea ',
#  'lmao  natur hair iv seen ugli swear',
#  'thank rt rose much appreci ',
#  'keep chang fe14 icon dont know one pick ',
#  'need answer ',
#  'around tom ',
#  'that fair enough  rush back either',
#  'phl abu dhabi love bless hihihi  teamjanuaryclaim 100 godonna',
#  'anytim ',
#  'pleasur d enjoy day',
#  'cant get anywher ',
#  'photo randi 9bi beauti physiqu shave uncut tattoo sexi boi ',
#  'step puddl  im wear slipper',
#  'onlin ',
#  ' ty mne pro pchelok ja   thank',
#  'look fun snapchat luceleva 21 snapchat kikgirl porno nude omegl countrymus sexysasunday ',
#  ' im litro gonna weekend',
#  'follow follow u back ',
#  'sound cool bet float though ',
#  ' awesom ',
#  'yeah look ',
#  'make u feel better never see anyon kpop flesh d',
#  'would email donnaestrydomwesterncapegovza  ta',
#  '',
#  'amin ',
#  'goodafternoon  gudday',
#  'mirror selfi ',
#  'dream went colleg fail anim    ',
#  'exactli d',
#  '9 shop like fri without ketchup tasteless  wsalelov',
#  '5so calum 5so luke 5so ashton 5so hey guy pleas follow   chelni   ',
#  'youngja get handsom im ',
#  'hahahahaha law make happen would heartbeat d',
#  'slept day cant sleep ',
#  'realli like interact sunni offer help dongsaeng chorong friendship among idol ',
#  'thank share enjoy app wish wick weekend ',
#  'gamer follow train follow retweet follow retweet gain activ follow  120',
#  'get free cornetto cant figur  x',
#  '30 minut count pass edsa ayala tunnel  still complet ',
#  'hey marti glad see twitter ',
#  'scream happi bday fav boy whole wide world         love  big 18 ',
#  'dang  pon thought time final come otl',
#  ' special offer rrp  1899 price  1399  ',
#  'aw ',
#  'sorri delay naomi ',
#  'thank follow enjoy tweet  let friend ambr suzan 268 4',
#  'discrimin  matern discrimin need boss kick teeth  uniteblu tcot',
#  'encourag employ board stuck poster ',
#  'shall d shall shout roof top social media p',
#  'thank eric mention ou may want consid  ',
#  'kebun ador spot ubud wait ladyposs  better place xoxoxo',
#  'babe ',
#  'corner fuck dope get addict  great job d',
#  'miss ',
#  'oh horrif ',
#  'lol big beauti appli sunglass jacki sunni never go style ',
#  'nakakapikon yung nagbabasa ka ng blog comment info full peopl ask damn question answer post ',
#  'could get free solo dm give away  xoxo',
#  'cost 600 k  get secur alert odoo 8 odoo partner far commun spirit ',
#  'hi emili im fan wish much happi life funni beauti happi birthday d',
#  'last dick pic got aw ruin walnut whip life  also name turn wife follow',
#  'cute look fabul ',
#  'actual go d yayayayay gonna first yt convent 3',
#  'hi bam follow bestfriend love lot  see warsaw 3 love 3 x9',
#  'otl nevermind  least got jeon',
#  'follow thank pleas follow ',
#  'bodi system want accept food ',
#  'harumph soggi  hope go weed',
#  'let go parti  pant ew  gross',
#  'great viabl altern nowaday ',
#  'hello  get youth job opportun follow',
#  'im look influenc app  interest here invit',
#  'want room ',
#  'omg happi late birthday im sorri miss  love though hope lot fun  ',
#  'wow miss long hair brace softbal ',
#  'taxi emptier ciara concert ',
#  'achiev excel music music produc mind boggl fatigu job  baareeq    ',
#  'good lord ',
#  '12pm ',
#  'miss ',
#  'guy stop pleas  zayniscomingbackonjuli 26',
#  'thank d',
#  'count p 28 bnte hain p',
#  'ok rich kid give ',
#  'school come twitter ',
#  'thank bae ',
#  'awww  kaya yan think posit',
#  ' ok',
#  'stuck centr right clown right joker left  ',
#  'thank follow ',
#  'cant go sleep normal time ',
#  'drama korea 49 day ',
#  'ye inconsider ',
#  'love thank share ',
#  'yay anoth vine love pleas vine peyton ',
#  'kind feedback truli made day perfect way end work week ',
#  'look like final time get rid old 2500k ',
#  'lucki ',
#  'actual type 1111 laptop took forev tweet ',
#  'guy realli unlucki one driver briefli check egg half spot',
#  'thank tweet ',
#  'hey lesley sorri get shall send post tonight ',
#  'ever let forgiv ',
#  'wow vw bu lot umpfff love ',
#  'feet cold point take sock okay stop ',
#  'two week close day redecor expect someth littl differ readi second birthday ',
#  'along fever ',
#  'let help get book publish ebook print let us help launch selfpublish  let',
#  'afti p',
#  'origin ticket  19 ',
#  'wet holiday friday  consol cafe sophi grigson amaz carrot cake',
#  'im osad ',
#  'wait nude ',
#  'spazz everyth soobin danc ',
#  'iv whisper today day four time week im still lie bed lay pokemon ',
#  'kik guy beeti 697 kik kikmeguy kikm makeup sex video kikkomansabor ',
#  'oh yeah definit go tri tonight  took advic treviso',
#  'guy buy u water u cant drink u watch cup like hawk transfer bartend u ',
#  'hate day  ',
#  'hi bam follow bestfriend love lot  see warsaw 3 love 3 x46',
#  '1 though ',
#  'didnt money time  would',
#  'get 7th win ',
#  'ngga usah dipikirin elah cant easili say someon who entp  reason',
#  'tessnzach cute account ',
#  'omg that sweet thing say thank  yeah use go saudi arabia lot dad',
#  'tempt eat whole pack oreo need find strength ',
#  'smile hide pain  ',
#  'that good ',
#  'soo gotten phone taken away im current sneak mum phone im gonna inact week ',
#  'haaretz israel  syria continu develop chemic weapon offici tell wsj wsj rep  uniteblu tcot',
#  'yeah that last time plan file polic complaint much yell switch place ',
#  'oh mr pig turn  although there weird crackl nois plug come plug im think fuse',
#  'come hous ',
#  'kik senight 468 kik kikmeboy gay teen amateur travel hotscratch ',
#  'im thank someon like life inspir better everyday love mind follow ',
#  'lol d',
#  'see tomorrow ',
#  'sorri mr 25 ',
#  'thrill first intern assign aerial camera oper  wale come boom never forget smile',
#  'ill sit android phone like ',
#  'tyler hipster glass d',
#  'that damn lie ',
#  'late ',
#  'what wrong ',
#  'haha indirect best friend ',
#  'readi  poldi cimbom',
#  'mad wrong  make forgiv ',
#  'well say delet twitter app 3 week ago liter download sorri ',
#  'sucki saturday ',
#  'haha that great ',
#  'follow follow u back ',
#  '4 hour ',
#  'babi boyfriend bitch know complet ',
#  'like way said gal lelomustfal beautiful way ',
#  'cant anymor cant stress bodi yet life base upon stress cant ',
#  'reign error exampl inflat rate sic ',
#  'ah ok wonder ',
#  'littl charl grown  rememb dy hair went rihanna red hahahaha aint ging xxx',
#  'insid happen today d',
#  'want someth new damn bill ',
#  'wit famili trip goa ',
#  'k ill text tomorrow ',
#  'omg nooo ',
#  'walk back breach  ',
#  'swag d',
#  'laper ',
#  'yeeeyyy congrat   gohf 2015 barsostay',
#  'thank follow keven ',
#  'drew alek d',
#  'miss netbal ',
#  '5g liker  like fast',
#  'year ago marri first love best friend thank amaz year glenn love wife ',
#  'thank retweet ',
#  'plant peopl allow thing everi thing p',
#  'visit blog thank d',
#  'mumma im 7 ',
#  'far would go win camara know  bride wore coveral romanc inspi',
#  'next ',
#  'read review sound awesom thank suggest ',
#  ' havent finish yet ',
#  'thx feedback glad gain valu ',
#  'vidcon ',
#  'still fulli intend write mani game design possibl attack plan next 6 month d',
#  'doin ok ',
#  'hi may like play newest gamejam game would happi ',
#  '',
#  'brother get piss ',
#  'cant announc cool show today wait monday thank ',
#  'work ',
#  '',
#  'ahhh last 2 stage go ',
#  'im tempt stream screenshot sjkao ',
#  'im die laughter bc dad keep play pou chang voic ',
#  'rlyyi wanna get septum pierc mum let ',
#  'damn cute ',
#  'follow thank pleas follow ',
#  'miss matt he come home 14 day know he go get back ',
#  'want pretzel  bb17 bblf',
#  'happi  see photo rescu mutt twitter ',
#  'iren unni bite finger worriedli stare staff  okay unni',
#  'sombrero high okay im lost ',
#  'sorna ',
#  'get iv tri age joy ',
#  'morn everyon wer open 12pm everi day sunday  hello weekend come say x',
#  'what score im stuck work ',
#  'make day smile ',
#  'need someon talk alway  keep head',
#  'becho ',
#  'com insonia ',
#  'remedi media tell ',
#  'much chanc game tonight  t20blast',
#  'yeeeah d ',
#  'flash  day long ',
#  'didnt get finish chop ',
#  ' okay worst',
#  'month sinc saw ',
#  'love ',
#  'thank d',
#  'happi happi birthday emili d',
#  'thank ',
#  'everyon els  xx',
#  'want chicken nugget ',
#  'also catch heck lot gun hater tri associ gun um endow  rude respons ',
#  'lepa dah sembuh ni sibuk balik okay la kin wont think anyth els except ur studi ',
#  'uff itna miss karhi thi ap p',
#  'school start pretti soon ',
#  'follow follow u back ',
#  'still happen lot unfortun still report peopl fall scam ',
#  'offer promethazin zopiclon sleep addit quetiapin modifi releas  typic iv paid prescript ',
#  'im amsterdam guy wooo d',
#  'snapchat tammirossm snapchat kikgirl kikchat wet wife indiemus sexi ',
#  'thank make tweet favourit ',
#  'lol 2am last night face though peopl think im perpetu piss sad b c rest bitchfac ',
#  'ye friendli contest loser buy drink ',
#  'thank donna  unev fine ',
#  'nice see peopl chang need fix care ',
#  'woke anoth migrain   need proper rest moment cant',
#  'friend respect life  im sorri',
#  'macbook p',
#  'done ',
#  'tri tweet unicef account answer ',
#  'truth could anyon would still choos ',
#  'thank work beagl amaz incred ',
#  'wrong turn 6 amaz movi bro ',
#  'keep calm stay kepo  d',
#  'nice dave d',
#  'kwento  fbc',
#  'braxton gone pro  feel bad urban unpreced brainwash see tebow alex smith',
#  'miss alreadi ',
#  'good ',
#  'pleas follow ',
#  'subserv ',
#  'd mainli mother want right haha other wait said  x',
#  'iv support sinc start alway ignor  pleas let today day final follow   ',
#  'feel look better peopl cant see tbh look tacki ',
#  'feel littl neglect visit posti today ',
#  'oh wow beauti tom ',
#  'imran khan innoc ',
#  'need clear head ',
#  'im crave oreo milk ',
#  '      love much believ will follow pleas follow pleas justin  x15 341        ',
#  'ff 3 ladi ',
#  'im play brain dot braindot',
#  'found goodwil gold today ',
#  'lol sorri ultor first hitter  favor much ',
#  'misundersrand day chal raha hai yhm ',
#  'wish   pleas get sign xxx',
#  'rbi make cage parrot 1li elect commiss cag r left power stripe gujarat model complet sad ',
#  'hello  ffback',
#  'scari dream cant go back sleep ',
#  'miss live hall  ',
#  ' love',
#  'ohh  well know find chang mind mayb even someon im close  xd',
#  'cleans scam ridden bodi vyapam go renam idea d d',
#  'shanzay salabrati ',
#  'oh gahd get well soon amber ',
#  'vault expand d',
#  'rli sad rush last time would see everyon ',
#  'pretti amaz hell 13 oh yeah play video game ',
#  'hi join today ',
#  'ahaha im lay bed like whyyi pretti wine glass suck ',
#  'sick mumma sick bubba cuddl  cuddl floor footi fall asleep ',
#  'certainli theme issu wev test rang devic w differ browser os ',
#  'ha ha  guess polit',
#  'one person still import  want gone longer  yet sit scare mind  ',
#  'told suicid kill ran away forev ',
#  'follow thank pleas follow ',
#  'sister wed tomorrow wer go hong kong leav 31st anoth horrif flight ',
#  'sad ',
#  'love u p',
#  'follow ',
#  'oh love lovelayyy thank ok kidney  want anyway p',
#  'life rememb one time year ago chang avi lost 72 follow loool ',
#  'today ',
#  'depend vet visit sick cat  ill let know',
#  'yup thank huhu mahirap ',
#  'learn new skill take time perfect master thank favourit ',
#  'hate wake middl sleep ',
#  'wanna skate rain ',
#  'wish would beat home numb mouth dentist visit ',
#  'thought true stop play feel guy  zayniscomingbackonjuli 26',
#  'thank  ',
#  'miss chri voic ',
#  'ishal mi ',
#  'got bed yet ',
#  'fback ',
#  'congrat launch d',
#  'phone charg 1 forev ',
#  'imagin news aayegi k 3 tim wiw bip zareen daisi  bcoz 2 tim normal kart hai  p',
#  'mommi ',
#  'sketchbook art love 4wild draw hair turn pretti cool d art hair color colorpencil cray ',
#  'okay get see morn that right ',
#  'haha feel nake without ole beardi tho ',
#  'got feel ariel bodi slap liter bodi slam ',
#  'hope one day hell fall love strong woman let see thing refus see ',
#  'sorri ',
#  'cant open door hard notic alreadi start song love live fail ',
#  'congratul realli look forward book good sunday morn view that awesom teapot btw  x',
#  'pleas dont postpon longer  ',
#  'know ',
#  'follow follow u back ',
#  'done yun ',
#  'what mean understand noth ',
#  'thought today pizza day sadli none manag usual buy ',
#  'jame wore meet greet ',
#  'need see boy ',
#  'congrat us d',
#  'hiii jack  ili   ',
#  'seem like go alot someth like  ',
#  'say exam exam na sa lune mart ',
#  'ty appreci recent retweet great friday ',
#  'one who dont see sins trend someth like that  zayniscomingbackonjuli 26',
#  'startup commun tropic geek beach  startupph',
#  'chanc find black guin wallet venu last night show lost wallet    thank',
#  'pet mous winner thank ',
#  'thank love d',
#  'sorri pooo ',
#  'ye think b stupid discuss abt wild card entri jst wait vivian perform ',
#  'ahh im sorri didnt repli back  miss also wouldv tweet u acc ive',
#  'didnt expect omg face  im proud infinit',
#  'laomma design kebaya wed dress bandung indonesia line laomma 7df89150 whatsapp 62 08962464174 7 instagram laommacoutur',
#  'dad said sorri ',
#  'throat sore ',
#  'ive email regard cours queri ',
#  'happi birthday jlo d forev jlover 3 love  come turkey pleas ',
#  'thank ',
#  'find old pictur long hair make sad ',
#  'save 21pic master nim say therer 22pic ask mani pic see ',
#  'good luck london weekend super result great support donetsk   ',
#  'awh good luck upgrad ',
#  'day day pa  compani mean  jk',
#  'happen kaussi ',
#  'usual high stool three kid wait toppl d',
#  'here    review phew wer liter overwhelm ',
#  'thq lot ur contin support thalaivar bro   ',
#  'deleici food follow sound 8 hr sleep never get time ',
#  'one best coupl ',
#  'thank much love im realli pleas ',
#  'bet plan secret babi shower chloe say bare know comput d',
#  'omg d tweetofthedecad p',
#  'rude ',
#  'batman cant fli cant help  habe fail ate',
#  'love dog moar naman haha one cat love much huhu cute 3 tara barkin blend tho d',
#  'good luck coupl get marri weekend ',
#  'fun gal  im go tri go sleep lol 415',
#  'follow ',
#  'made ',
#  'school final three week left im back san diego ',
#  'okkay ',
#  'istanya go 2suppli extra infrastructur teacher doctor nurs paramed countless thing 2cope ',
#  'smile beauti ',
#  'hi dm luke pleas ',
#  'got noth tonight there concert join jason rob feb tour ',
#  'hehe  smile ear ear d',
#  'great new opportun junior triathlet age 12 13 gatorad seri get entri ',
#  'interview newsround news hound 740 today ',
#  'book trip crisi ',
#  'iv move australia matter time ',
#  'said got much time hand  rogerwatch',
#  'scoup 17 like jren nuest d',
#  'whoop whoop  quacketyquack',
#  'sure watch pokiri 1nenokkadin tym fav  bajrangibhaijaanhighestweek 1',
#  'want want ',
#  'thank follow enjoy tweet  let friend gtagiveaway 624 179',
#  'hey guy ',
#  'word satir gener situat hurt much ',
#  'lose d',
#  'hello  tell still keep touch zayn ',
#  'follow thank pleas follow ',
#  'vidcon ',
#  'woohyun seem weird inspirit shine night   im ise see like  happen ',
#  'defin agre grow sport drop email detail see ',
#  'done eonni ',
#  'hi merlin current wait roof repair kitchen let water ',
#  'miss tom felton ',
#  'go ',
#  'okay ',
#  'stat day arriv 1 new follow unfollow  via',
#  'friend fatmam ',
#  '',
#  'suck ',
#  'school start next monday ohgod ',
#  'dang rad fanart d',
#  'rememb 2 gaon bad 6 infnt elig apink  acub whyd u',
#  'biggest dream u follow brooo ',
#  'play dota 2 d',
#  'want creat first bboy cardgam pixelart gamedesign d think indiedev pixeldaili gamedev',
#  'aww thank beauti pic d',
#  'love write  absolut ador nva lucki enough live 5 minuet away roll gamec',
#  'congratul ',
#  'hey like fnaf check youtub channel  via',
#  'well summer  knew last live britain    ',
#  'well  screw guy u keep smile ',
#  'thank follow us wonder friday  ff',
#  'aww  thank anyway',
#  'when birthday ',
#  'last day work munchkin today    bought littl part gift  far ',
#  'ughh got noth pain ',
#  'aspetti good bore chicken chip tea cupboard empti d',
#  'done yein ',
#  'pm ',
#  'home time today  dublin',
#  'wtf like lip still virgin omg mom get life your 45 hahah',
#  'glad like check nice stuff wsalelov ',
#  'hi bam follow bestfriend love lot  see warsaw 3 love 3 x2',
#  'past hoodi cover lot sin ',
#  'girl quick ',
#  'onlin ',
#  'easier said done ',
#  'good even better see around  yep way live freedom pistol good move',
#  'haw phela look like mom obvious look like ',
#  'thank ',
#  'im bore ',
#  'come man d d',
#  'sure let know around  side world eh u take care ',
#  'there certain group fandom na mahilig mambulli  bakit',
#  'short weekend ahead ',
#  'thank  ffback',
#  'peopl unfav rted ',
#  'someon sc ',
#  'gym week need big person push today get tonight  iv make excus lazi ',
#  'sorri matthew  3',
#  'discoveri cousin earth kepler 452b 1400 light yr away teleport possibl way arriv ',
#  'come fli babi  retweet marin navi airforc battlefield',
#  'care care  fahrinahmad tengkuaaronshah eksperimencinta d',
#  'im proud work hope enjoy let know view ',
#  'thank bundl show internet price phone realisticli pay net ',
#  'wish cut hair like ',
#  'add snapchat sexyameli 20 snapchat kikhorni likeforfollow kikmeboy likeforfollow newmus hornykik ',
#  'toss ladi ',
#  '        ',
#  '      love much believ will follow pleas follow pleas justin  x15 340        ',
#  'go zumba somewher els pleas studi ',
#  'want say huge thank ff thank support ',
#  'miss  still juja',
#  ' pleas follback  love ur voic  u   heheheh 3',
#  'congrat ',
#  'visit blog thank d',
#  'break shell ',
#  'add snapchat maryhick 18 snapchat kikmeboy photooftheday fuck chat musicbiz sheskindahot ',
#  'oh dear  xx',
#  'threaten ',
#  'nice line  ',
#  'fun tamesid ',
#  'love problem  ngarepfollbackdarinabilahjkt 48',
#  'think fifth album im  okay  fuck ',
#  'sore qt ',
#  'kik hearess 677 kik kikhorni hornykik babe chat countrymus txtshot ',
#  'way get bandana ',
#  '',
#  'miss tweet spree oh ',
#  'regret peanut butter sandwich rn sore mouth make thing difficult ',
#  'usa rosh travel  glasgow intern airport gla',
#  'thank ',
#  'im sorri ',
#  'yet  find eventu',
#  'ausfailia haha miss snow  live footi flight get day game count 2nd ye row',
#  'go home ',
#  ' hope chwang still drag eat later sob',
#  'fback ',
#  'funni next anim umaru d',
#  'one want go ant man ',
#  'bad im poor ',
#  'followfriday top support commun week ',
#  'wielli follback ya ',
#  'haha feel mayb that d',
#  'oh cool d hope like',
#  'sooo tire cant sleep ',
#  'want ihop ',
#  'aw  angek sbali euuuwww lunch like real construct worker ',
#  'sister best best pre bday celebr ',
#  'realli want ',
#  'im still awak ',
#  'enjoy ',
#  'zayniscomingbackonjuli 26 im cri hope zayn come back side want believ ',
#  'nice see famili member close miss ',
#  'woke upp cant sleep ',
#  'cool thank think hope well ',
#  'heyi  u rt link tag michael pleas thank',
#  'love chat cycl oxford campaign way home yesterday cycl rout pleas  cycl oxford',
#  'sure would good thing 4 bottom dare 2 say 2 miss b im gonna stubborn mouth soap nothavingit p',
#  'thank ',
#  'feel like im go throw ',
#  'gonna throw idea caus theyr bad inspir think someth much better ',
#  'im best perfect promis love whole heart ',
#  'im datz ',
#  'nein ',
#  'would drop 10 wine bottl spill wine work ',
#  'payday feel like payhour gone bill immedi ',
#  'hey guy know request product team alreadi consid ',
#  'taken  anoth chara mayb teteh',
#  'text die lurgi jim ',
#  'im gonna stay gold colour hope come soon thank anyway ',
#  'curri close home ',
#  'im hungri ',
#  'look mani peopl still think woman sex bigger vagina sigh ',
#  'ok ',
#  'dev verri sad caus twitter ',
#  'much seriou yun eh ',
#  'ahh chang sound cooler  lmao ye 2 minhyuk',
#  'gusto ko ng rodic  someon share order one big',
#  'want protect relationship other ill talk ppl need know awesom ',
#  'famish ',
#  'long distanc  ',
#  'agayhippiehippi follback ya ',
#  'sound nice d',
#  'wish london  gonna stay airport bit go citi',
#  'day life video upp om 60 minut d',
#  'cant wait rosa love xma  welcom back ann hope u good one back time  x',
#  'thought best day paper town today ',
#  'rli wanna spend christma rel yr ',
#  'want brace back ',
#  'bro choos takraw ',
#  'oh   terribl ',
#  'thank becca ',
#  'earth assum rain london like influenc overal warm dri past week continent europ ',
#  'love episod skip doomsday episod pleas ',
#  'here life lesson teach kid weekend ',
#  'wish b8 strong ',
#  'final home drive sinc 5am ',
#  'happi weekend everyon smile lot ',
#  'hope nate notic edit sinc made icon ',
#  'poor noggin bump day ago still hurt littl  feelslikeanidiot',
#  'neither  excit    xxx',
#  '5 20 w kurta mom half number d wsalelov',
#  'ping im watch tl like hawk d',
#  'follow thank pleas follow ',
#  'layout match closest could find header  someon help',
#  'ohh happyfriday thank love team ',
#  'peanut probabl crash   seen drive monash ',
#  'nighter ',
#  'aw bless made smile im miss ',
#  'omg ',
#  'dude get dm ',
#  'need small ladi walk back sore  ',
#  'aw  switch ',
#  'iv happi late ',
#  ' maverickgam juli 24 2015 0717 pm ',
#  'thank retweet ',
#  'feel better ',
#  'happi save day  hope enjoy meal sam',
#  'grow shorter pl ',
#  'yeah tri film date start time film 4 day left ',
#  'think hard bed p',
#  'ty d love d use background till remov background',
#  'like back   done ',
#  'bad headach right trip ',
#  'pl ',
#  'want bandana bottl set huhuh ',
#  'yawn good morn everyon wag tail everyon today d',
#  'see id get eyebrow done prettylook wanna tri differ style ',
#  'yeah dude keep calm brace ',
#  'followfriday top engag member commun week ',
#  ' ye sometim pass ',
#  'thank welcom hope goe brilliantli ',
#  'recent trip j k total love d that chenab flow pakistan incredibleindia',
#  'hope shamuon right tokyo ',
#  'riprishikeshwari soul rest peac ',
#  'ye avail d wanna join',
#  'art thou ',
#  'hi would like concert let know citi countri ill start work thank ',
#  'hey thank follow  autofollow teamfollowback via',
#  'need massag ',
#  'wonder happen earlier realiz leadership  wakeupgop',
#  'follow thank pleas follow ',
#  'u greet birthday  even dmed u ',
#  ' mari',
#  'agre 100 ',
#  'hallo ',
#  'awww thank guy wish wick weekend  travel safe x',
#  'realli need miracl happen today  4th win pleas ',
#  'im sure wasnt anyth wer alreadi use  glad ur home',
#  'thank take time tweet kat ',
#  'sc long ',
#  'alway welcom dear    good afternoon   ',
#  'know dumb think johnni rock u seen utub video mad respect d',
#  'awww thank ',
#  'got stung wasp im cri hard tweak keep get bigger ive never stung one hope im allerg ',
#  'tshirt d awesom',
#  'yay ok d',
#  'greekcrisi greek leav work abroad gave light word remain dark  ',
#  'studi mcdo strong selfi game everywher ',
#  'angel must confus anoth doctor  besteverdoctorwhoepisod',
#  'glad like ',
#  'mum ',
#  'here cute panda make day ',
#  'dare run corridor ',
#  'gave away last night didnt hear anybodi ',
#  'thank retweet friend ',
#  'molli deserv much higher place ',
#  'rip tom moor  love read comic book  anoth great artist truli miss ',
#  'that shame thought get somewher abandon talk disagre w get us nowher ',
#  'askip texist pa ',
#  'ikr  lol',
#  'morn ',
#  ' rakyat keep visit blog read write ',
#  'bosen ',
#  ' care  namecheck bring like dog whistl without',
#  'thank follow great connect ',
#  'there noth cool total someon bitter anger hatr toward pure indiffer ',
#  'cold cough ',
#  ' wna go church',
#  'get free gold w  download world tank  easi  click aqui d',
#  'fantast night ',
#  'happi birthday ',
#  'hello  get youth job opportun follow',
#  '',
#  'oh okay sure soon enough ',
#  'pleas throw awesom smile lilsisbro  hope career alway success',
#  'midland ye thank depress weather forecast word rain mention sever time ',
#  'lol im lazi learn ps ',
#  'post pic outfit today hashtag  fashionfriday  upload later today blog join fun',
#  'disgust  wish peopl respect',
#  'aww damn  haha',
#  'emon',
#  'realli good luck ',
#  'wanna live world peopl get shot go cinema louisianashoot ',
#  'follow facebook ',
#  'thank much mean everyth even know never follow back ',
#  's2 air spain delay kill us  ',
#  'tato bulat d',
#  'headach ',
#  'luckili one mani ',
#  'sort  thank daaru parti chaddi bro',
#  'face skinni pictur omg  get fat',
#  'unfortun seat left coach k well parti quietli  dh',
#  'pure talent  alway fan deepxcap brother talent   ',
#  'feel like movi popcorn today cinema  one go ',
#  'showbox thing work naruto cartoon let keep finger cross isnt end favourit work companion ',
#  'home gg ',
#  'heart rate ridicul today ',
#  'thank  post 1 everi night  usual jami ian  ',
#  'wip let get thing tweak ill link  max kal tak',
#  'collect   retweet',
#  'thank head ear defend wer readi listen  btw call mobil use 0330 333 7234',
#  'ah keep goin sweeti   big hug x',
#  'jgh go bayan d bye',
#  'food poison ',
#  'idea ure say ',
#  'yo gimm month free bill sinc servic pretti much everi day ',
#  'mean put rat lol ',
#  'phone shit alway run memori   2 mani nude',
#  'luv ur ',
#  'hanaaa birthday ya allah sorri wish van jn tak tau  happi birthday gorgeou',
#  'stage time portsmouth live  x',
#  'twitter said  u follow   ',
#  'what hashtag weekend guy ',
#  'thank share wish wick weekend ',
#  'know make lini kasi  sad that im sweat kanina init pa huhu',
#  'need boyfriend rn answer calll ',
#  'actual gonna start 1 pm ',
#  'hell go wrong  understand peopl choos hurt',
#  'asian sjw tri cri  d',
#  'struggl find perfect glass small structur face real ',
#  'know like dj snake perform vid con todayyy ',
#  'hous scari af night ',
#  'taimoor meray dost ',
#  'oo pre im sick  huhu sad hahaha',
#  'sad ',
#  'thank ad us list  make sure keep touch news light bulb made corn wast',
#  'im work ',
#  'movie buddyyi ',
#  'suk buttt except pumpkin scone  havent made year ',
#  'given kepler 452b distanc propos far away suitabl name perhap fan comment suggest altern ',
#  'song the fifth album notr readi hwi niall cute ',
#  'time jhalak bore   concept bakwa   old concept much better interest     ',
#  'd ty bbi',
#  'like ballad  think emphasi vocal lot im happi chose promot one',
#  'followfriday top support commun week ',
#  'tri support uk citizen sign ',
#  'start rain soon im readi run  damn',
#  'good morn d lol realli fuckin dark gonna rain hard coupl minut',
#  'smi  oh wait   kid nemesi still rule',
#  'heavi duti benadryl lmao dat shit work forgot take earlier ',
#  'your gonna guess what insid box ',
#  'want friend go concert ',
#  'infinit im sorri  cant stream ',
#  'unit oppress mass take forev  look wat happen n afghanistn war tore end n',
#  'mayb younger woman stamina tom ',
#  'hi wer sorri hear  log abl see inform need',
#  'take care ',
#  'angelo face listen yna  psygustokita',
#  'yeah classi look  iv seen peopl attach sort life save equip bed fix 0',
#  'im stefani  real one ',
#  'thank follow great day ',
#  'thirsti ',
#  'peopl scream much fight  hurt throat stop ',
#  'read david tweet think damn one month summer left suck realiz start colleg august 24th ',
#  'back delhi ',
#  'thank ',
#  'time awww conni forget checkout brilliant music vid youtub follow us ',
#  'realli help  altern give us call 150 0345 454 111 help mka',
#  'sneaker day  nike nikeorigin nikeindonesia pierojogg skoy',
#  'hey pleas check final design ',
#  'tri work ',
#  'waduh  pant ',
#  'wait hq pic today add yoona x hairpin otp collect d',
#  'yeah exactli ',
#  'awkward moment feel got ab cant stop laugh read tweet d',
#  'wacki d',
#  'sort d santorini come escap',
#  'awh what chanc  u zant need someth  x',
#  'know say know ',
#  'soo hot sunnyday sunshin sun smile lol ',
#  'want add ',
#  'miss ',
#  'sunday morn stream also birthday stream follow usual birthday procedur play grim fandango d',
#  'find major peopl except va im sure kept lumin km ',
#  'omg alli hug mani wrap arm around neck pull closer ',
#  'walk fruit shop lot pumpkin guy smile look pretti funni matter work ',
#  'iv want chang woohyun one sunggyu make feel guilti ',
#  ' zayn ',
#  'therapi exhaust want lie somewher cant ',
#  'smile make smile ',
#  'well absolut chuckin ampsha  rain rain rain',
#  'im reason ok',
#  'welcom thank explor retweet ',
#  'best burger far agre  retweet food burger',
#  'two day im buri email  ',
#  'amen thank ',
#  'wanna go hous rn give big big hug ',
#  'ohh hii  haha thank info ill check  mayb di nagsend yung order form ko 3 haha thank ulit ',
#  'hate first win yet ',
#  'check youtub link might like anoth person tri live dream ',
#  'giant balloon want one ',
#  'taeni fyeah link broken ',
#  'hahaha go doug ',
#  'sorri na  next time prami ',
#  'ff best pal furbabi  luff hug 4 weekend  x',
#  '   pimpl    forehead   size    volcano ',
#  'group lourd bang  ',
#  'see flickr pro back ',
#  'wish happi friday  xxx',
#  'agre dutch sound im sure im legibl  im legibl isra passport law return',
#  'im go sleep upset ',
#  'im ',
#  'u get call tp law ',
#  'hi love u  ',
#  'thing go wrong go wrong broken manual wheelchair check get one fit nh 26week wait ',
#  'ugh yuck  make sure rest next two day',
#  'weak dom  dom techniqu',
#  'miss half music bank bc groceri shop  good thing final hubba bubba bubbl gum 3',
#  'still want harriet leav though ',
#  'thank shout guy ',
#  'wish  zayniscomingbackonjuli 26',
#  'need get use wake alon ',
#  'pain ubericecream driver busi ',
#  'leed wanna see live ',
#  'hey thank follow ',
#  'introduc new word vs alter understand word x spread either big problem ',
#  'ghost bae d love tagsforlikesapp instagood smile follow cute photooftheday tbt ',
#  'wish parent would live forev ',
#  'aint gonna follow ',
#  'follow back ',
#  'thank much  glad like  ',
#  'need special medicin son kidney cant afford bought printer ink last week ',
#  'oop  server error occur email sent  ',
#  'dont snapchat ',
#  'five night freddy 4 night 1 d',
#  'nuf teas alreadi show us alien everyday seem get closer see alien cousin ',
#  'stat week arriv 2 new follow unfollow  via',
#  'feel free share other ',
#  'wtf bodi goal ',
#  'ugh  head hurt',
#  'hello  get youth job opportun follow',
#  'thank wonder reader like rose make worthwhil love weekend ',
#  'that like hear lot bubbl pleas  quacketyquack',
#  'went tokyo station dinner  good see someon kansai area kunoriforceo ceo 1month',
#  'supposedli one worst kernel devic ',
#  'head kill ',
#  'big thx 4 kind support good luck ',
#  'zayniscomingbackonjuli 26  ',
#  'need relax   lungomar pesaro giachietittiwed igersoftheday summertim summer ',
#  'wanna go movi today one ',
#  'happi birthday cess ',
#  'heeeyyy follow fan account thank ',
#  'love ',
#  'like rose ',
#  'okeyyy vddd   excit cant wait  love selfee pic insta    special coco              dishoom',
#  'poor sbenu sasin happi  best player team   anarchi 3 3',
#  'babyy ',
#  'thing need ',
#  ' money    ',
#  'yeah 2 key guess gave mine d',
#  'bore time  know ',
#  'ugh want right right need ya tay one understand ',
#  'hi saw u follow thought u might like dark plz let us know u think ',
#  'saturday class ',
#  'wft  cant watch awesom replay ',
#  'long day week viparita karani legsupthewal perfect pose unwind  enjoy ',
#  'finish day 33 plan bibl 90 day check 2 chronicl 23 complet ',
#  'lost 34 k ',
#  'miss apink perform ',
#  'gut one peopl abl final meet ',
#  'sad moment ',
#  'doubt im go bed soon though  wake like 9',
#  'ive got much thing 3 day  syawal',
#  'hmm think get one might get one int futur realli miss buckl spring ',
#  'yosh ',
#  'feel ill today ',
#  'ye your right  sad mani intoler scare xenophob ',
#  'eleph also enjoy tast uniqu marula fruit ',
#  'im get olli tweet notif ',
#  'get holiday cloth day like wanna go ',
#  'bbut favorit thing gintama shinsengumi special chapter ',
#  'one japan pop artist becom one follow ig  nice ',
#  'miss kid cant believ im adult stuff like pay rent bill degre shit like fuck ',
#  'gleam jazz origin paint thank lot retweet  x',
#  'alway tell take nap abl sleep night like alway take nap ',
#  'pleas fra hope u pick ',
#  'place hope   pro remot work travel ',
#  'rickyfeb follback ya ',
#  'crave chicken wing ',
#  'call throwbackfriday christen ki yaad aa gayi d',
#  'snapchat shoshannavassil snapchat hornykik selfi gay porn quot camsex ',
#  'lucki spike ',
#  'hi max film gaza month back would love retweet think good enough ',
#  'got half ',
#  'chem lt nice ',
#  'love  want corn chip ',
#  'well done good get thing way ',
#  'grepe grepein ',
#  'awesom ',
#  'pegel lemess n d',
#  'morn beauti  neil today sweeti xxx',
#  'cat love snuggl right face love never breath ',
#  'happinesss ',
#  'anoth amaz video kev  proud wonder support wonder person ',
#  'naeun  bodi goal ',
#  'come ',
#  'nstp class tomorrow ',
#  'woah okay expect tweet fucker die ',
#  'iv support sinc start alway ignor  pleas let today day final follow    ',
#  'fineandyu take gd pic like tri hurt ',
#  'haha whatev jess know thought surri hill near botani ',
#  'im gonna miss u sexi prexi ',
#  'high time  v sad',
#  'welcom ',
#  '  ',
#  ' thank mario  wonder friday  ',
#  'follow ',
#  'one brave enough watch snapchat stori ',
#  'watch concert film ',
#  'ourdaughtersourprid mypapamyprid proud papa coach ',
#  'thank  weekend tri best ',
#  'ur actual watch smh bff ye hashtag bc u love jk omfg im hyper ',
#  'thank wendi let friend yaa ',
#  'tri stay watch game work ',
#  'strang kareena fan know kareena fan ',
#  'know feel ',
#  'miss ',
#  'aitor sn would mind check bio particip ps4 giveaway could winner ',
#  'nice tee man ',
#  ' friday d',
#  'welcom d',
#  'like eye d',
#  'thank everyon came show tip ',
#  'recharg normal come charger u buy ',
#  'ha thought made sure ',
#  'anybodi around penrith emu plain see giant hard miss pleas let know import ',
#  'thank omar ',
#  'want stay till infinite win 530 alreadi ',
#  'good morn fab friday ',
#  'love u 2 ',
#  'final grade class ',
#  'stock sa 1 hour ',
#  'come thru b miss ',
#  'damn hope deserv one sinc age sinc last repack wont mention boy group get repack alway ',
#  'even talk comput im data convers done gone wrong cri ',
#  'liter give get gener ticket tri one time final got g ',
#  ' that long time',
#  'read beauti like read ',
#  'sorri alway chang layout ',
#  'think matt ever get back togeth stay friend ',
#  'miss goal  10 real',
#  'fantast brilliant news ',
#  'hahahaha rememb clearli p',
#  'thank come ladi love see  know either',
#  '',
#  'omaygad didnt know vic got surgeri  there amber  tttt',
#  'say bday ',
#  'funni use kuffar comput cell phone social media spread diarrhea though immigr lice d',
#  'go see tonight son choic film glad hear worth watch ',
#  'shock news  riptito',
#  'im kinda sort fuck ',
#  'love blue eye ',
#  'want world hulk hogan scrub wwe histori ',
#  'appar isnt ',
#  'stat day arriv 1 new follow unfollow  via',
#  'enjoy treat young ',
#  'hii vin plss rpli tweet ',
#  'hi meg sent email verity perform cancel weekend  rupert',
#  'hey lynn fb buffer button bring compos buffer fb share  mari',
#  'sorri cant hope ',
#  'ff happyfriday great friday ',
#  'bring  boatbound bring luxuri yacht mass tech via',
#  'lmaoo mca team gettin hella money dm u wana make fast bandz asap ',
#  'right ',
#  'love conni fabul ship amaz crew staff great time ',
#  'want look good ',
#  'final went drive tonight ',
#  'well receiv necessari ',
#  'happen ',
#  'civ 5 crash middl marathon game  ',
#  'ahh thank u d',
#  'fave unfollow   ',
#  'cool look ',
#  'brb go somewher im forc go ',
#  'babi boy ',
#  'happyfriday anyth relat need help give us call 01482 333505 ',
#  ' realliampayn pleas follow  wait follow back  pleas follow back retweet repli ',
#  'bag job sanza ',
#  'hi paul that good hear  dm inform happen contact us',
#  'hi would like concert let know citi countri ill start work thank ',
#  'morn realli d ur alreadi fun caus weekend right d ure futur  amaz night',
#  'hi bam follow bestfriend love lot  see warsaw 3 love 3 x30',
#  'haaa would miss ',
#  'duh emesh p',
#  'oop ',
#  ' sad cwnt help',
#  'zayn start small letter z ',
#  'jmu camp teas bc wanna ',
#  'go die im sorri ',
#  'im sorri sweeti  one deserv',
#  'miss ',
#  'et brotherhood steel ',
#  'realiz 3 watch concert video pcd extrem hard rn ',
#  'actual 1 hehe  live strang imagin ',
#  'yeah play pretti girl bu stop  x',
#  'hi georg cant see sell im afraid  sorri thank beth',
#  'follow follow u back ',
#  'guy blue eye d',
#  'ye babi kaya im sorri ',
#  'first love wanna fuck late night think got nut  v look ',
#  'hey think im gonna asthma attack inhal omg r u gonna ok yeah u took breath away ',
#  'want sleep ',
#  'hi melani  fact theyr realli use case normal wifi could issu mention ',
#  'tht iv wrong  powerpoint present expect diner nono either',
#  'fri pleas ',
#  'lone sometim call number get busi tone ',
#  'nice day queen ',
#  'one  perhap someth els 877 2fm',
#  'lyka follow back na ',
#  'stuff well  would know ',
#  'hope feel better jay ',
#  'im hungri ',
#  'go home tomorrow ',
#  'nickyyi wtf  ',
#  'fback ',
#  'yeah noth stop king franc d nice day',
#  'shoulda let borrow one knive d',
#  'feel like lifetim finish day  parti time xxx',
#  'oh d',
#  'great regret get sign copi deathofgrass john ad thank loan lawnmow ',
#  'follow thank pleas follow ',
#  ...]

# %%
generate_word_cloud(output_list_x, "WordCloud for Test Dataset")
generate_bar_graph(output_list_x)

# %%
total_sentences = positive_tweets + negative_tweets

# %%
sentence_lengths = [len(sentence) for sentence in total_sentences]

# %%
import seaborn as sns

# %%
data_input_sentence_character_length = pd.Series(sentence_lengths)

# Create a histogram with a density curve
plt.figure(figsize=(10, 6))
plt.title("Number of characters in a sentence")
sns.histplot(data=data_input_sentence_character_length, kde=True)
# Out:
# <AxesSubplot:title={'center':'Number of characters in a sentence'}, ylabel='Count'>

# %%
sentence_word_counts = [len(sentence.split()) for sentence in total_sentences]

# %%
data_input_word_length = pd.Series(sentence_word_counts)

# Create a histogram with a density curve
plt.figure(figsize=(10, 6))
plt.title("Number of words in a sentence")
sns.histplot(data=data_input_word_length, kde=True)
# Out:
# <AxesSubplot:title={'center':'Number of words in a sentence'}, ylabel='Count'>
